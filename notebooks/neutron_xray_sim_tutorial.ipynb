# %% [markdown]
# # Neutron / X-ray Dual-Modality Tomography Simulation
# ## Bimodal Histogram Analysis — Tutorial v3
#
# This notebook walks through the complete `neutron_xray_sim` pipeline:
#
# | § | Topic |
# |---|-------|
# | 0 | Setup & imports |
# | 1 | Material database |
# | 2 | Phantom construction |
# | 3 | Forward projection |
# | 4 | Artifact configuration |
# | 5 | CT reconstruction (all algorithms) |
# | 6 | Bimodal histogram analysis |
# | 6b | Volume segmentation |
# | 7 | High-level simulation orchestrator |
# | 8 | Misalignment sweep |
# | 9 | Batch runs |
# | **10** | **File-system cache — save & reload every pipeline stage** |
# | **11** | **Artifact survey (all algorithms, metrics embedded)** |
# | **12** | **Cross-algorithm bimodal histogram grid** |
# | **13** | **Cluster-quality metrics & algorithm ranking** |
# | 14 | Save figures |
#
# > **v3 changes:** sections 10–13 are new; §5 shows all nine algorithms;
# > §7 adds `cache_dir`; §10 demonstrates `SimCache` save/reload;
# > §11 uses the updated `run_artifact_survey` with embedded DB/CE metrics;
# > §12 uses `plot_cross_algorithm_grid`; §13 uses `compare_algorithms`.

# %% [markdown]
# ## Corrections applied (v1.1 → v3)
#
# * **Sample size** 10 cm → 1 cm (`voxel_cm = 1/N`).
# * **Neutron μ**: imaging-effective values (Lehmann 2010, Boillat 2018) replace total cross-sections.
# * **FBP shadow bug**: custom numpy back-projector replaced by `skimage.iradon`.
# * **Nine reconstruction algorithms** now available: FBP, GRIDREC, SIRT, SART, CGLS, EM, OSSART, TV_MIN, NESTEROV_SIRT.
# * **File-system cache** (`SimCache`): every stage saved as `.npy` automatically.
# * **Artifact survey** now returns metrics and embeds DB/CE in panel titles.
# * **`plot_cross_algorithm_grid`**: compare mixed-algorithm combinations on the bimodal histogram.

# %% [markdown]
# ---
# ## 0 · Setup

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path('neutron_xray_sim').parent.resolve()))

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams.update({'figure.dpi': 110, 'axes.titlesize': 10})
# %matplotlib inline

import neutron_xray_sim as nxs
from neutron_xray_sim.io import SimCache
from neutron_xray_sim.histogram import (
    plot_cross_algorithm_grid,
    make_cross_algorithm_sinos,
    evaluate_histogram_quality,
    compare_algorithms,
)

print(f'neutron_xray_sim v{nxs.__version__} loaded.')
print('Available algorithms:', nxs.AVAILABLE_ALGORITHMS)
print('Available phantoms:  ', list(nxs.PHANTOM_PRESETS.keys()))

import requests
# Out:
# neutron_xray_sim v1.0.0 loaded.
# Available algorithms: ['FBP', 'GRIDREC', 'SIRT', 'SART', 'CGLS', 'EM', 'OSSART', 'TV_MIN', 'NESTEROV_SIRT']
# Available phantoms:   ['composite', 'battery', 'bone_implant', 'industrial']
# <frozen importlib._bootstrap>:241: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
BOT_TOKEN = "BOT-TOKEN"
CHAT_ID = "CHAT-ID"

def send_message(text):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendMessage"
    payload = {"chat_id": CHAT_ID,"text": text}
    r = requests.post(url,json=payload)
    return r.json()

def send_image(image_path):
    url = f"https://api.telegram.org/bot{BOT_TOKEN}/sendPhoto"
    with open(image_path,"rb") as img:
        r = requests.post(url, data={"chat_id": CHAT_ID},files={"photo":img})
    return r.json()

# %% [markdown]
# ---
# ## 1 · Material Database

# %% [markdown]
# Every material stores:
# - **`mu_n`** — total thermal-neutron linear attenuation [cm⁻¹]
# - **`_mu_x_table`** — X-ray μ at 13 energies (NIST XCOM, 20–300 keV)
# - **`rho`** — mass density [g/cc]

# %%
print(f"{'Material':<18} {'ρ (g/cc)':>10} {'μ_n (cm⁻¹)':>12} {'μ_x @80keV':>12}")
print('─' * 58)
for name, mat in nxs.MATERIALS.items():
    print(f"{name:<18} {mat.rho:>10.3f} {mat.mu_n:>12.4f} {mat._mu_x_table[6]:>12.4f}")
# Out:
# Material             ρ (g/cc)   μ_n (cm⁻¹)   μ_x @80keV
# ──────────────────────────────────────────────────────────
# air                     0.001       0.0000       0.0001
# water                   1.000       1.3800       0.1840
# aluminum                2.700       0.0980       0.2780
# hdpe                    0.950       2.1800       0.1670
# iron                    7.870       1.1600       4.1200
# titanium                4.510       0.6400       1.4800
# copper                  8.960       1.1200       4.9200
# lead                   11.350       0.3730      22.8000
# bone                    1.920       0.5600       0.4690
# tungsten               19.300       1.5600      88.0000
# zinc                    7.130       0.3500       3.2500

# %%
fig, ax = plt.subplots(figsize=(7, 5))
colours = plt.cm.Set1(np.linspace(0, 0.9, len(nxs.MATERIALS)))
for (name, mat), col in zip(nxs.MATERIALS.items(), colours):
    ax.scatter(mat._mu_x_table[6], mat.mu_n, s=90, color=col,
               edgecolors='k', linewidths=0.6, zorder=3)
    ax.annotate(mat.symbol, (mat._mu_x_table[6], mat.mu_n),
                xytext=(4, 4), textcoords='offset points', fontsize=8)
ax.set_xlabel(r'$\mu_x$ at 80 keV [cm$^{-1}$]'); ax.set_ylabel(r'$\mu_n$ [cm$^{-1}$]')
ax.set_title('Material positions in the bimodal attenuation space')
ax.grid(True, alpha=0.3); plt.tight_layout(); plt.show()

# %%
# X-ray spectrum visualisation
from neutron_xray_sim.materials import xray_spectrum
fig, axes = plt.subplots(1, 2, figsize=(11, 4))
for kVp, col in [(80, 'steelblue'), (120, 'tomato'), (140, 'seagreen')]:
    E, W = xray_spectrum(kVp, filter_mm_Al=2.0, n_bins=30)
    axes[0].plot(E, W, label=f'{kVp} kVp', color=col)
    axes[1].plot(E, np.cumsum(W), label=f'{kVp} kVp', color=col)
for ax, title in zip(axes, ['Spectral weights', 'Cumulative weight']):
    ax.set_xlabel('Energy [keV]'); ax.set_ylabel('Weight'); ax.legend()
    ax.set_title(title); ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 2 · Phantom Construction

# %% [markdown]
# Four preset phantoms are available: `composite`, `battery`, `bone_implant`, `industrial`.
# Change `PRESET` and `N` to explore different objects.

# %%
# ── Global simulation parameters (shared by all sections below) ──────────
PRESET   = 'composite'   # 'composite' | 'battery' | 'bone_implant' | 'industrial'
N        = 512            # voxel grid (use 128–512 for publication quality)
N_ANGLES = 600           # projection angles (use 360–1200 for publication)

phantom = nxs.make_phantom(PRESET, N)
print(phantom)
print('Materials:', [m.name for m in phantom.materials])
# Out:
# PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
# Materials: ['Air', 'Aluminum', 'HDPE', 'Water', 'Iron', 'Titanium']

# %%
# ── Central orthogonal slices of the neutron attenuation volume ──────────
si = N // 2
slices = [
    ('μ_n  XY', phantom.mu_n_vol[si, :, :]),
    ('μ_n  XZ', phantom.mu_n_vol[:, si, :]),
    ('μ_n  YZ', phantom.mu_n_vol[:, :, si]),
]
fig, axes = plt.subplots(1, 3, figsize=(11, 3.5))
for ax, (title, sl) in zip(axes, slices):
    im = ax.imshow(sl, cmap='viridis', origin='lower')
    ax.set_title(title, fontsize=10); ax.axis('off')
    plt.colorbar(im, ax=ax, fraction=0.046, label='cm⁻¹')
fig.suptitle(f'{PRESET} phantom — neutron attenuation slices', fontsize=11)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 3 · Forward Projection

# %% [markdown]
# X-ray: polychromatic Beer-Lambert sum (beam hardening emerges naturally).
# Neutron: three-component thermal model (absorption + coherent + incoherent scatter).

# %%
KVP       = 120.0
AL_FILTER = 2.0

xray_sino, neut_sino = nxs.make_sinogram_pair(
    phantom,
    n_angles        = N_ANGLES,
    angle_range_deg = 360.0,
    kVp             = KVP,
    filter_mm_Al    = AL_FILTER,
    n_spectrum_bins = 12,
    I0_xray         = 1e5,
    I0_neutron      = 1e5,
    use_astra       = True,
)
print('X-ray sinogram :', xray_sino['sino_lam'].shape,
      '  (n_angles, N_slice, N_det)')
print('Neutron sinogram:', neut_sino['sino_lam'].shape)
# Out:
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# X-ray sinogram : (600, 512, 512)   (n_angles, N_slice, N_det)
# Neutron sinogram: (600, 512, 512)

# %%
# ── Visualise central sinogram slices ─────────────────────────────────────
s = N // 2
fig, axes = plt.subplots(1, 2, figsize=(11, 4))
for ax, sino, title in zip(axes,
        [xray_sino['sino_lam'][:, s, :], neut_sino['sino_lam'][:, s, :]],
        ['X-ray log-attenuation sinogram', 'Neutron log-attenuation sinogram']):
    im = ax.imshow(sino, aspect='auto', cmap='gray', origin='lower')
    ax.set_xlabel('Detector pixel'); ax.set_ylabel('Projection angle')
    ax.set_title(title)
    plt.colorbar(im, ax=ax, label='OD')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 4 · Artifact Configuration

# %% [markdown]
# | Flag | Domain | Bimodal histogram signature |
# |------|--------|-----------------------------|
# | `photon_noise` | sino | Cluster broadening; blobs merge at low I₀ |
# | `apply_bh_correction=False` | sino | μ_x cupping — dense clusters shift left |
# | `neutron_scatter` | sino | All clusters shift up along μ_n |
# | `xray_scatter` | sino | All clusters shift left along μ_x |
# | `detector_psf` | sino | Cluster broadening; stronger in μ_n |
# | `ring_artifacts` | sino | Vertical stripes at specific μ_x values |
# | `misalignment` | vol | Horizontal streaks at each material's μ_n |

# %%
configs_demo = [
    nxs.ArtifactConfig.clean(),
    nxs.ArtifactConfig.noise_only(I0=5e4),
    nxs.ArtifactConfig.scatter_only(),
    nxs.ArtifactConfig.misalignment_only(),
    nxs.ArtifactConfig.realistic(),
]
for cfg in configs_demo:
    print(cfg.summary())

# %%
# ── Custom config ─────────────────────────────────────────────────────────
custom_cfg = nxs.ArtifactConfig(
    photon_noise              = True,
    I0_xray                   = 5e4,
    I0_neutron                = 5e4,
    neutron_scatter           = True,
    scatter_fraction          = 0.06,
    scatter_sigma_pixels      = 9.0,
    detector_psf              = True,
    psf_sigma_xray_pixels     = 0.8,
    psf_sigma_neutron_pixels  = 1.5,
)
print('Custom config:', custom_cfg.summary())

# %% [markdown]
# ---
# ## 5 · CT Reconstruction

# %% [markdown]
# Nine algorithms are available. Select one with `ALGORITHM` below.
#
# | Algorithm | Type | GPU | Notes |
# |-----------|------|-----|-------|
# | `FBP` | analytic | optional | Fast; ramp filter; ringing artefacts |
# | `GRIDREC` | analytic | no | Fourier gridding; needs TomoPy |
# | `SIRT` | iterative | yes | Best H₂O/HDPE separation |
# | `SART` | iterative | yes | Recommended default |
# | `CGLS` | iterative | yes | Fast; needs regularisation |
# | `EM` | iterative | yes | ML-EM; enforces positivity |
# | `OSSART` | iterative | yes | Ordered-subset SART; fastest iterative |
# | `TV_MIN` | iterative | yes | Total-variation; piecewise-constant |
# | `NESTEROV_SIRT` | iterative | yes | Nesterov momentum; ~1.7× faster than SIRT |
#
# ```python
# from neutron_xray_sim import AVAILABLE_ALGORITHMS
# print(AVAILABLE_ALGORITHMS)
# ```

# %%
from neutron_xray_sim.artifacts import inject_sinogram_artifacts, inject_volume_artifacts

# ── Inject sinogram-domain artifacts ──────────────────────────────────────
x_sino_art, n_sino_art = inject_sinogram_artifacts(
    {k: v.copy() if isinstance(v, np.ndarray) else v for k, v in xray_sino.items()},
    {k: v.copy() if isinstance(v, np.ndarray) else v for k, v in neut_sino.items()},
    custom_cfg,
)

# %%
# ── Choose algorithm and reconstruct ──────────────────────────────────────
ALGORITHM   = 'SART'         # change to any of the nine algorithms above
FILTER_NAME = 'shepp-logan'  # for FBP / GRIDREC only
N_ITER      = 30             # for all iterative algorithms
N_SUBSETS   = 10             # for OSSART only
LAMBDA_TV   = 0.02           # for TV_MIN only

vol_x, vol_n = nxs.reconstruct_pair(
    x_sino_art, n_sino_art,
    algorithm    = ALGORITHM,
    filter_name  = FILTER_NAME,
    n_iter       = N_ITER,
    n_subsets    = N_SUBSETS,
    lambda_tv    = LAMBDA_TV,
    remove_rings = True,
    use_astra    = True,
    clip_negative= True,
)

# Apply volume-domain artifacts (misalignment etc.)
vol_x, vol_n = inject_volume_artifacts(vol_x, vol_n, custom_cfg)

print(f'vol_x: {vol_x.shape}  [{vol_x.min():.3f}, {vol_x.max():.3f}] cm⁻¹')
print(f'vol_n: {vol_n.shape}  [{vol_n.min():.3f}, {vol_n.max():.3f}] cm⁻¹')

# %%
# ── Reconstructed central slices ──────────────────────────────────────────
si = N // 2
fig, axes = plt.subplots(2, 3, figsize=(11, 7))
for col, (vx_sl, vn_sl, lbl) in enumerate([
        (vol_x[si],       vol_n[si],       'XY'),
        (vol_x[:, si, :], vol_n[:, si, :], 'XZ'),
        (vol_x[:, :, si], vol_n[:, :, si], 'YZ'),
]):
    vmin_x, vmax_x = np.percentile(vol_x, [1, 99])
    vmin_n, vmax_n = np.percentile(vol_n, [1, 99])
    axes[0, col].imshow(vx_sl, cmap='gray', vmin=vmin_x, vmax=vmax_x)
    axes[0, col].set_title(f'X-ray {lbl} — {ALGORITHM}'); axes[0, col].axis('off')
    axes[1, col].imshow(vn_sl, cmap='gray', vmin=vmin_n, vmax=vmax_n)
    axes[1, col].set_title(f'Neutron {lbl} — {ALGORITHM}'); axes[1, col].axis('off')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 6 · Bimodal Histogram Analysis

# %% [markdown]
# The joint 2-D histogram H(μ_x, μ_n) is the diagnostic core.
# Pure-material voxels form compact Gaussian clusters; interface voxels trace
# straight partial-volume bridges between adjacent cluster centres.

# %%
hist = nxs.compute_bimodal_histogram(vol_x, vol_n, bins=128)
print(f'Histogram shape: {hist.H.shape}  total voxels: {hist.total_voxels:,}')

# %%
# Ground truth vs reconstruction
gt_hist = nxs.compute_ground_truth_histogram(phantom, bins=128)
fig = nxs.plot_ground_truth_comparison(
    phantom, hist,
    title_gt    = 'Ground Truth (exact positions)',
    title_recon = f'Reconstructed — {ALGORITHM}',
    show_marginals = True,
)
plt.show()

# %%
# Single histogram with marginals
fig = nxs.plot_bimodal_histogram(
    hist,
    title          = f'Bimodal histogram — {PRESET} / {ALGORITHM}',
    show_marginals = True,
    log_scale      = True,
)
plt.show()

# %%
# GMM fitting
n_true = len(phantom.materials)
gmm = nxs.auto_fit_gmm(hist, min_k=max(2, n_true-1), max_k=n_true+2)
print(f'GMM: k={gmm.n_components}  BIC={gmm.bic:.0f}  AIC={gmm.aic:.0f}')

fig = nxs.plot_bimodal_histogram(
    hist, gmm=gmm,
    title=f'Bimodal histogram + GMM ({gmm.n_components} components)',
    show_marginals=True,
)
plt.show()

# %%
# Artifact signature metrics
sigs = nxs.detect_artifact_signatures(hist)
print(f'Horizontal streak (misalignment proxy) : {sigs.horizontal_streak_score:.4f}')
print(f'Vertical streak   (ring artifact proxy) : {sigs.vertical_streak_score:.4f}')
print(f'Diagonal smear    (BH / scatter proxy)  : {sigs.diagonal_smear_score:.4f}')
print(f'μ_n shift         (neutron scatter)     : {sigs.marginal_shift_n:.4f} cm⁻¹')

# %% [markdown]
# ---
# ## 6b · Volume Segmentation from Histogram

# %%
label_vol = nxs.segment_by_gmm(vol_x, vol_n, gmm)
gt_labels = phantom.label_vol

si = N // 2
cmap_seg = plt.cm.get_cmap('tab10', gmm.n_components)
cmap_gt  = plt.cm.get_cmap('tab10', n_true)

fig, axes = plt.subplots(2, 3, figsize=(11, 7))
for col, lbl in enumerate(['XY', 'XZ', 'YZ']):
    idx = (si, slice(None), slice(None)) if lbl == 'XY' else \
          (slice(None), si, slice(None)) if lbl == 'XZ' else \
          (slice(None), slice(None), si)
    axes[0, col].imshow(gt_labels[idx], cmap=cmap_gt,
                        vmin=0, vmax=n_true-1)
    axes[0, col].set_title(f'GT labels {lbl}'); axes[0, col].axis('off')
    axes[1, col].imshow(label_vol[idx], cmap=cmap_seg,
                        vmin=0, vmax=gmm.n_components-1)
    axes[1, col].set_title(f'GMM labels {lbl}'); axes[1, col].axis('off')
fig.suptitle('Ground-truth vs GMM segmentation', fontsize=11)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 7 · High-Level Simulation Orchestrator

# %% [markdown]
# `DualModalitySimulation` manages the full pipeline in one object.
# Raw sinograms are computed **once** and cached so subsequent runs with
# different artifact configs reuse them.
#
# **New in v3:** pass `cache_dir` to persist every stage to disk automatically.
# See §10 for the full cache workflow.

# %%
# ── Create simulation (with optional disk cache) ──────────────────────────
sim = nxs.DualModalitySimulation(
    preset    = PRESET,
    N         = N,
    n_angles  = N_ANGLES,
    algorithm = 'SART',
    auto_gmm  = False,
    verbose   = True,
    # cache_dir = 'results/composite_SART',  # ← enable to save to disk
)

# %%
r_clean   = sim.run(nxs.ArtifactConfig.clean(),           tag='clean')
r_noise   = sim.run(nxs.ArtifactConfig.noise_only(I0=5e4), tag='noise_moderate')
r_scatter = sim.run(nxs.ArtifactConfig.scatter_only(),     tag='scatter')
r_misalign= sim.run(
    nxs.ArtifactConfig(misalignment=True,
                       translation_voxels=(3, 0, 0)),
    tag='misalign_3vx',
)
r_real    = sim.run(nxs.ArtifactConfig.realistic(),         tag='realistic')

# %%
# ── Comparison grid ───────────────────────────────────────────────────────
all_results = [r_clean, r_noise, r_scatter, r_misalign, r_real]
fig = sim.comparison_grid(all_results, ncols=3)
plt.show()

# %%
# ── Slice comparison ──────────────────────────────────────────────────────
fig = sim.comparison_slices(all_results)
plt.show()

# %%
# ── Artifact signature table ──────────────────────────────────────────────
print(sim.signature_table(all_results))

# %% [markdown]
# ---
# ## 8 · Misalignment Sweep

# %%
DISPLACEMENTS = [0.0, 0.5, 1.0, 2.0, 3.0, 5.0, 8.0]   # voxels

sim_sweep = nxs.DualModalitySimulation(
    preset=PRESET, N=N, n_angles=N_ANGLES,
    algorithm='SART', verbose=False,
)

sweep_results = []
ref_r = sim_sweep.run(nxs.ArtifactConfig.clean(), tag='0 vx (clean)')
sweep_results.append(ref_r)

for d in DISPLACEMENTS[1:]:
    cfg_d = nxs.ArtifactConfig(
        misalignment=True,
        translation_voxels=(d, 0.0, 0.0),
    )
    r = sim_sweep.run(cfg_d, tag=f'{d:.1f} vx', ref_result=ref_r)
    sweep_results.append(r)

# %%
# ── Streak score vs displacement ──────────────────────────────────────────
scores = [r.signatures.horizontal_streak_score for r in sweep_results]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4.5))
ax1.plot(DISPLACEMENTS, scores, 'o-', color='tomato', lw=2, ms=7)
ax1.set_xlabel('Translation misalignment [voxels]')
ax1.set_ylabel('Horizontal streak score')
ax1.set_title('Streak score vs misalignment')
ax1.grid(True, alpha=0.3)

# Overlay the 0-vx and 3-vx histograms for comparison
for r, col, lbl in [
        (sweep_results[0], 'steelblue', '0 vx'),
        (sweep_results[DISPLACEMENTS.index(3.0)], 'tomato', '3 vx'),
]:
    H = r.histogram.H.T
    H = np.log1p(np.ma.masked_where(H == 0, H))
    ax2.contour(H, levels=6, colors=[col], alpha=0.7,
                extent=r.histogram.extent)
    ax2.plot([], [], color=col, label=lbl)
ax2.set_xlabel(r'$\mu_x$ [cm$^{-1}$]'); ax2.set_ylabel(r'$\mu_n$ [cm$^{-1}$]')
ax2.set_title('Histogram contours: 0 vx vs 3 vx')
ax2.legend(); ax2.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 9 · Batch Runs

# %%
batch_configs = [
    ('clean',            nxs.ArtifactConfig.clean()),
    ('noise high',       nxs.ArtifactConfig(photon_noise=True, I0_xray=1e4, I0_neutron=1e4)),
    ('noise low',        nxs.ArtifactConfig(photon_noise=True, I0_xray=5e3, I0_neutron=5e3)),
    ('beam hardening',   nxs.ArtifactConfig(apply_bh_correction=False)),
    ('BH corrected',     nxs.ArtifactConfig(apply_bh_correction=True)),
    ('n scatter mild',   nxs.ArtifactConfig(neutron_scatter=True, scatter_fraction=0.04)),
    ('n scatter strong', nxs.ArtifactConfig(neutron_scatter=True, scatter_fraction=0.12)),
    ('rings',            nxs.ArtifactConfig(ring_artifacts=True, n_bad_columns=4)),
    ('psf',              nxs.ArtifactConfig(detector_psf=True, psf_sigma_neutron_pixels=2.5)),
    ('misalign 3vx',     nxs.ArtifactConfig(misalignment=True, translation_voxels=(3,0,0))),
    ('realistic',        nxs.ArtifactConfig.realistic()),
]

sim_batch = nxs.DualModalitySimulation(
    preset=PRESET, N=N, n_angles=N_ANGLES,
    algorithm='SART', verbose=False,
)
batch_results = sim_batch.run_batch(batch_configs, ref_tag='clean')
print('Batch done. Runs:', list(batch_results.keys()))

# %%
print(sim_batch.signature_table())

# %%
fig = sim_batch.comparison_grid(ncols=4,
    suptitle=f'Batch artifact survey — {PRESET} / SART')
plt.show()

# %% [markdown]
# ---
# ## 10 · File-System Cache — Save and Reload Every Pipeline Stage  ★ new in v3

# %% [markdown]
# The `SimCache` class saves every pipeline stage as `.npy` files.
# On the next run, expensive steps (phantom build, GPU projection,
# iterative reconstruction) are skipped if the files already exist.
#
# **Directory layout:**
# ```
# results/composite_SART/
# ├── phantom/               label_vol.npy, mu_x_vol_*.npy, mu_n_*_vol.npy, meta.json
# ├── sinograms/             xray_sino_lam.npy, neutron_sino_lam.npy, sino_meta.json
# └── runs/
#     └── clean/             vol_xray.npy, vol_neutron.npy,
#                            histogram_H.npy, histogram_*edges.npy, run_meta.json
# ```
#
# After the survey is saved you can reload any stage independently
# and re-run only the analysis — no GPU required.

# %%
CACHE_DIR = 'results/composite_SART_cache'

# ── Run with cache enabled ─────────────────────────────────────────────────
sim_cached = nxs.DualModalitySimulation(
    preset    = PRESET,
    N         = N,
    n_angles  = N_ANGLES,
    algorithm = 'SART',
    verbose   = True,
    cache_dir       = CACHE_DIR,  # ← enable cache
    overwrite_cache = True,       # overwrite if already exists
)

rc_clean = sim_cached.run(nxs.ArtifactConfig.clean(),           tag='clean')
rc_noise = sim_cached.run(nxs.ArtifactConfig.noise_only(I0=5e4), tag='noise_moderate')
rc_real  = sim_cached.run(nxs.ArtifactConfig.realistic(),        tag='realistic')

print('\nSaved tags:', sim_cached.cache.list_run_tags())

# %%
# ── Inspect the cache directory ────────────────────────────────────────────
import os
for root, dirs, files in os.walk(CACHE_DIR):
    level = root.replace(CACHE_DIR, '').count(os.sep)
    indent = '  ' * level
    print(f'{indent}{os.path.basename(root)}/')
    for f in sorted(files):
        size = os.path.getsize(os.path.join(root, f)) / 1e6
        print(f'{indent}  {f:45s}  {size:.2f} MB')

# %%
# ── Reload without re-running the simulation ──────────────────────────────
from neutron_xray_sim.io import SimCache
from neutron_xray_sim.histogram import compute_bimodal_histogram

cache = SimCache(CACHE_DIR)
print('Tags in cache:', cache.list_run_tags())

# Load a saved volume pair and recompute the histogram with different binning
vol_x_reload = cache.load_run_volume('clean', 'xray')
vol_n_reload = cache.load_run_volume('clean', 'neutron')
hist_reload  = compute_bimodal_histogram(vol_x_reload, vol_n_reload, bins=256)

print(f'Reloaded volume shape:    {vol_x_reload.shape}')
print(f'Recomputed histogram bins: {hist_reload.H.shape}')

# %%
# ── Load a raw sinogram and reconstruct with a different algorithm ─────────
# (no forward projection needed — sinogram already on disk)
x_sino_reloaded = cache.load_raw_xray_sino()
n_sino_reloaded = cache.load_raw_neutron_sino()

print('Sinogram shape:', x_sino_reloaded['sino_lam'].shape)
print('angles:', x_sino_reloaded['angles_deg'].shape)

# Reconstruct with SIRT from the cached sinogram
vol_x_sirt, vol_n_sirt = nxs.reconstruct_pair(
    x_sino_reloaded, n_sino_reloaded,
    algorithm='SIRT', n_iter=30, use_astra=True,
)
hist_sirt = compute_bimodal_histogram(vol_x_sirt, vol_n_sirt, bins=128)
print('SIRT reconstruction from cached sinogram complete.')

# %%
# ── Re-run only the histogram analysis step ────────────────────────────────
print('Re-running histogram + metrics for all cached runs...')
for tag in cache.list_run_tags():
    vx = cache.load_run_volume(tag, 'xray')
    vn = cache.load_run_volume(tag, 'neutron')
    h  = compute_bimodal_histogram(vx, vn, bins=128)
    m  = evaluate_histogram_quality(h, sim_cached.phantom)
    print(f"  {tag:<22s}: DB={m.davies_bouldin:.4f}  CE={m.mean_centroid_error:.4f} cm⁻¹")

# %%
# ── Save survey metrics CSV ────────────────────────────────────────────────
# Collect the three results into a metrics dict, then export to CSV.
from neutron_xray_sim.histogram import evaluate_histogram_quality

survey_metrics = {}
for tag, r in [('clean', rc_clean), ('noise_moderate', rc_noise), ('realistic', rc_real)]:
    survey_metrics[tag] = evaluate_histogram_quality(
        r.histogram, sim_cached.phantom
    )

cache.save_survey_metrics('intro_survey', survey_metrics)
print('Metrics CSV saved.')

# Load back as a list of dicts (compatible with pandas)
rows = cache.load_survey_metrics_csv('intro_survey')
for row in rows:
    print(f"  {row['tag']:<20s}  DB={float(row['davies_bouldin']):.4f}")

# %% [markdown]
# ---
# ## 11 · Artifact Survey (all algorithms, embedded metrics)  ★ updated in v3

# %% [markdown]
# `run_artifact_survey` runs 14 standardised artifact scenarios
# (10 single + 4 combinations) and produces the publication-quality
# survey grid.  In v3 each panel now shows:
# - **DB** = Davies-Bouldin index (cluster separability; lower = better)
# - **CE** = mean centroid error [cm⁻¹] (positional accuracy; lower = better)
#
# A ranked summary table is printed to stdout after reconstruction.
#
# The function returns a **third** value — `metrics` — a dict of
# `ClusterQualityMetrics` objects, one per artifact panel.

# %%
from neutron_xray_sim import run_artifact_survey
import os; os.makedirs('output_surveys', exist_ok=True)

SURVEY_N       = N        # increase to 512 for publication figures
SURVEY_ANGLES  = N_ANGLES  # increase to 600

# %%
# ── Run survey for a single algorithm ─────────────────────────────────────
results_sart, fig_sart, metrics_sart = run_artifact_survey(
    preset              = PRESET,
    N                   = SURVEY_N,
    n_angles            = SURVEY_ANGLES,
    algorithm           = 'SART',
    compute_metrics     = True,   # embeds DB + CE in every panel title
    include_combinations= True,
    verbose             = True,
)
fig_sart.savefig('output_surveys/survey_SART.png', dpi=150, bbox_inches='tight')
print('Saved output_surveys/survey_SART.png')
plt.show()
send_message("Survey is done")
# Out:
# [sim] Loading phantom 'composite' at N=512 …
# [sim] PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
#
# ════════════════════════════════════════════════════════════
#   Artifact survey: 14 runs on 'composite' phantom (N=512)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Clean (reference)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Computing raw sinograms (cached for subsequent runs) …
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Clean (reference)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.800] cm⁻¹
#   μ_n range : [0.000, 2.586] cm⁻¹
#   Runtime   : 54.5 s
#   Signatures:
#     horiz_streak  = 114.420
#     vert_streak   = 110.457
#     diag_smear    = 0.512
#     x_asymmetry   = 0.2038
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise moderate
# (I₀=5×10⁴)'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise moderate
# (I₀=5×10⁴)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.576] cm⁻¹
#   μ_n range : [0.000, 2.772] cm⁻¹
#   Runtime   : 33.2 s
#   Signatures:
#     horiz_streak  = 117.529
#     vert_streak   = 110.519
#     diag_smear    = 0.572
#     x_asymmetry   = 0.2032
#     n_shift       = 0.0006 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise low dose
# (I₀=5×10³)'
# [sim] Artifacts: noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise low dose
# (I₀=5×10³)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.669] cm⁻¹
#   μ_n range : [0.000, 3.080] cm⁻¹
#   Runtime   : 34.8 s
#   Signatures:
#     horiz_streak  = 122.538
#     vert_streak   = 110.488
#     diag_smear    = 0.723
#     x_asymmetry   = 0.2105
#     n_shift       = 0.0074 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (no BHC)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (no BHC)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.476] cm⁻¹
#   μ_n range : [0.000, 2.653] cm⁻¹
#   Runtime   : 23.3 s
#   Signatures:
#     horiz_streak  = 114.492
#     vert_streak   = 110.512
#     diag_smear    = 0.511
#     x_asymmetry   = 0.2034
#     n_shift       = -0.0002 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (BHC corrected)'
# [sim] Artifacts: BHC(order=3)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (BHC corrected)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BHC(order=3)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.427] cm⁻¹
#   μ_n range : [0.000, 2.661] cm⁻¹
#   Runtime   : 25.8 s
#   Signatures:
#     horiz_streak  = 114.625
#     vert_streak   = 110.541
#     diag_smear    = 0.506
#     x_asymmetry   = 0.2065
#     n_shift       = -0.0001 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Neutron scatter
# (f=6%)'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Neutron scatter
# (f=6%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.532] cm⁻¹
#   μ_n range : [0.000, 2.529] cm⁻¹
#   Runtime   : 31.5 s
#   Signatures:
#     horiz_streak  = 121.518
#     vert_streak   = 114.478
#     diag_smear    = 0.592
#     x_asymmetry   = 0.2043
#     n_shift       = -0.0380 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'X-ray scatter
# (f=4%)'
# [sim] Artifacts: BH_artifact(no_correction) | x_scatter(f=0.04)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'X-ray scatter
# (f=4%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | x_scatter(f=0.04)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.414] cm⁻¹
#   μ_n range : [0.000, 2.607] cm⁻¹
#   Runtime   : 34.0 s
#   Signatures:
#     horiz_streak  = 116.832
#     vert_streak   = 116.742
#     diag_smear    = 0.437
#     x_asymmetry   = 0.2540
#     n_shift       = -0.0002 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)'
# [sim] Artifacts: BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.884] cm⁻¹
#   μ_n range : [0.000, 2.510] cm⁻¹
#   Runtime   : 34.2 s
#   Signatures:
#     horiz_streak  = 114.341
#     vert_streak   = 110.918
#     diag_smear    = 0.499
#     x_asymmetry   = 0.2011
#     n_shift       = -0.0028 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Ring artifacts
# (3 bad cols)'
# [sim] Artifacts: BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Ring artifacts
# (3 bad cols)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.640] cm⁻¹
#   μ_n range : [0.000, 2.576] cm⁻¹
#   Runtime   : 22.7 s
#   Signatures:
#     horiz_streak  = 114.522
#     vert_streak   = 110.662
#     diag_smear    = 0.510
#     x_asymmetry   = 0.2035
#     n_shift       = -0.0006 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Misalignment
# (3 vx, 1°)'
# [sim] Artifacts: BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Misalignment
# (3 vx, 1°)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.596] cm⁻¹
#   μ_n range : [0.000, 2.609] cm⁻¹
#   Runtime   : 28.8 s
#   Signatures:
#     horiz_streak  = 97.429
#     vert_streak   = 106.487
#     diag_smear    = 0.451
#     x_asymmetry   = 0.2033
#     n_shift       = -0.0082 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + misalign'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + misalign' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.810] cm⁻¹
#   μ_n range : [0.000, 2.778] cm⁻¹
#   Runtime   : 43.2 s
#   Signatures:
#     horiz_streak  = 117.659
#     vert_streak   = 110.472
#     diag_smear    = 0.588
#     x_asymmetry   = 0.2038
#     n_shift       = -0.0062 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Scatter (n+x) + PSF'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Scatter (n+x) + PSF' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.328] cm⁻¹
#   μ_n range : [0.000, 2.528] cm⁻¹
#   Runtime   : 56.2 s
#   Signatures:
#     horiz_streak  = 123.323
#     vert_streak   = 121.055
#     diag_smear    = 0.519
#     x_asymmetry   = 0.2519
#     n_shift       = -0.0399 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + BH + rings'
# [sim] Artifacts: noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + BH + rings' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.634] cm⁻¹
#   μ_n range : [0.000, 2.754] cm⁻¹
#   Runtime   : 40.2 s
#   Signatures:
#     horiz_streak  = 118.595
#     vert_streak   = 110.543
#     diag_smear    = 0.597
#     x_asymmetry   = 0.2043
#     n_shift       = 0.0012 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'All realistic'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'All realistic' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.414] cm⁻¹
#   μ_n range : [0.000, 2.571] cm⁻¹
#   Runtime   : 76.8 s
#   Signatures:
#     horiz_streak  = 118.242
#     vert_streak   = 117.957
#     diag_smear    = 0.516
#     x_asymmetry   = 0.1823
#     n_shift       = -0.0402 cm⁻¹
#
# [survey] Computing cluster-quality metrics (14 runs)…
#
#   Cluster quality — SART survey
#   (ranked by Davies-Bouldin index, lower = better)
#   ──────────────────────────────────────────────────────────────
#   Artifact scenario                     DB index  Mean CE [cm⁻¹]
#   ──────────────────────────────────────────────────────────────
#   All realistic                           0.7070          0.5757
#   Detector PSF (σ_x=0.8, σ_n=1.5 px)      0.7175          1.0725
#   Clean (reference)                       0.7240          0.9897
#   Beam hardening (BHC corrected)          0.7271          0.9636
#   Misalignment (3 vx, 1°)                 0.7428          1.0800
#   Beam hardening (no BHC)                 0.7439          1.0863
#   Ring artifacts (3 bad cols)             0.7502          1.0866
#   Noise + misalign                        0.7591          1.1065
#   X-ray scatter (f=4%)                    0.8427          0.7108
#   Scatter (n+x) + PSF                     0.8757          0.5546
#   Noise low dose (I₀=5×10³)               0.8780          0.5805
#   Noise + BH + rings                      0.8952          0.5957
#   Noise moderate (I₀=5×10⁴)               0.9044          0.5769
#   Neutron scatter (f=6%)                  1.0403          0.5513
#   ──────────────────────────────────────────────────────────────
#
# Saved output_surveys/survey_SART.png
# {'ok': True,
#  'result': {'message_id': 2359,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776335872,
#   'text': 'Survey is done'}}

# %%
# ── Inspect per-panel metrics ──────────────────────────────────────────────
print(f"{'Artifact panel':<35s}  {'DB index':>10}  {'Mean CE':>16}")
send_message(f"{'Artifact panel':<35s}  {'DB index':>10}  {'Mean CE':>16}")
print('─' * 66)
for tag, m in metrics_sart.items():
    clean_tag = tag.replace('\n', ' ')
    print(f"{clean_tag:<35s}  {m.davies_bouldin:>10.4f}  {m.mean_centroid_error:>16.4f}")
    send_message(f"{clean_tag:<35s}  {m.davies_bouldin:>10.4f}  {m.mean_centroid_error:>16.4f}")
send_message("Metrics of survey finished")
# Out:
# Artifact panel                         DB index           Mean CE
# ──────────────────────────────────────────────────────────────────
# Clean (reference)                        0.7240            0.9897
# Noise moderate (I₀=5×10⁴)                0.9044            0.5769
# Noise low dose (I₀=5×10³)                0.8780            0.5805
# Beam hardening (no BHC)                  0.7439            1.0863
# Beam hardening (BHC corrected)           0.7271            0.9636
# Neutron scatter (f=6%)                   1.0403            0.5513
# X-ray scatter (f=4%)                     0.8427            0.7108
# Detector PSF (σ_x=0.8, σ_n=1.5 px)       0.7175            1.0725
# Ring artifacts (3 bad cols)              0.7502            1.0866
# Misalignment (3 vx, 1°)                  0.7428            1.0800
# Noise + misalign                         0.7591            1.1065
# Scatter (n+x) + PSF                      0.8757            0.5546
# Noise + BH + rings                       0.8952            0.5957
# All realistic                            0.7070            0.5757
# {'ok': True,
#  'result': {'message_id': 2377,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776350076,
#   'text': 'Metrics of survey finished'}}

# %%
# ── Run survey for all algorithms and collect clean-run metrics ───────────
# This is the definitive four-algorithm comparison used in the paper.
# For N=512 and n_angles=600 each run takes ~10–30 min on GPU.

send_message("Starting multiple algorithm survey")

all_algorithms = ['FBP', 'SIRT', 'SART', 'CGLS']  # add 'EM', 'TV_MIN', ...
clean_results_by_alg = {}

for alg in all_algorithms:
    print(f'\n=== Survey: {alg} ===')
    results_alg, fig_alg, metrics_alg = run_artifact_survey(
        preset          = PRESET,
        N               = SURVEY_N,
        n_angles        = SURVEY_ANGLES,
        algorithm       = alg,
        compute_metrics = True,
        verbose         = True,
    )
    fig_alg.savefig(f'output_surveys/survey_{alg}.png',
                    dpi=150, bbox_inches='tight')
    plt.close(fig_alg)

    # Keep the clean-run result and its metrics for the ranking table
    clean_tag = 'Clean (reference)'
    if clean_tag in results_alg:
        r = results_alg[clean_tag]
        r.tag = alg            # rename for compare_algorithms table
        clean_results_by_alg[alg] = {
            'result':  r,
            'metrics': metrics_alg.get(clean_tag),
        }

print('\nAll surveys complete.')
send_message("All surveys complete.")
# Out:
# === Survey: FBP ===
# [sim] Loading phantom 'composite' at N=512 …
# [sim] PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
#
# ════════════════════════════════════════════════════════════
#   Artifact survey: 14 runs on 'composite' phantom (N=512)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Clean (reference)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Computing raw sinograms (cached for subsequent runs) …
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Clean (reference)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.937] cm⁻¹
#   μ_n range : [0.000, 2.298] cm⁻¹
#   Runtime   : 48.2 s
#   Signatures:
#     horiz_streak  = 58.420
#     vert_streak   = 60.626
#     diag_smear    = -0.004
#     x_asymmetry   = 0.1064
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise moderate
# (I₀=5×10⁴)'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise moderate
# (I₀=5×10⁴)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 11.232] cm⁻¹
#   μ_n range : [0.000, 2.928] cm⁻¹
#   Runtime   : 27.8 s
#   Signatures:
#     horiz_streak  = 103.791
#     vert_streak   = 102.999
#     diag_smear    = 0.148
#     x_asymmetry   = 0.1102
#     n_shift       = 0.0101 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise low dose
# (I₀=5×10³)'
# [sim] Artifacts: noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise low dose
# (I₀=5×10³)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.032] cm⁻¹
#   μ_n range : [0.000, 4.400] cm⁻¹
#   Runtime   : 29.2 s
#   Signatures:
#     horiz_streak  = 122.747
#     vert_streak   = 100.438
#     diag_smear    = 0.754
#     x_asymmetry   = 0.1545
#     n_shift       = 0.0401 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (no BHC)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (no BHC)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.937] cm⁻¹
#   μ_n range : [0.000, 2.298] cm⁻¹
#   Runtime   : 15.9 s
#   Signatures:
#     horiz_streak  = 58.420
#     vert_streak   = 60.626
#     diag_smear    = -0.004
#     x_asymmetry   = 0.1064
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (BHC corrected)'
# [sim] Artifacts: BHC(order=3)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (BHC corrected)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BHC(order=3)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.761] cm⁻¹
#   μ_n range : [0.000, 2.298] cm⁻¹
#   Runtime   : 17.0 s
#   Signatures:
#     horiz_streak  = 59.304
#     vert_streak   = 59.622
#     diag_smear    = -0.004
#     x_asymmetry   = 0.1080
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Neutron scatter
# (f=6%)'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Neutron scatter
# (f=6%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.937] cm⁻¹
#   μ_n range : [0.000, 2.218] cm⁻¹
#   Runtime   : 23.1 s
#   Signatures:
#     horiz_streak  = 86.659
#     vert_streak   = 86.438
#     diag_smear    = 0.028
#     x_asymmetry   = 0.1065
#     n_shift       = -0.0613 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'X-ray scatter
# (f=4%)'
# [sim] Artifacts: BH_artifact(no_correction) | x_scatter(f=0.04)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'X-ray scatter
# (f=4%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | x_scatter(f=0.04)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.611] cm⁻¹
#   μ_n range : [0.000, 2.298] cm⁻¹
#   Runtime   : 26.7 s
#   Signatures:
#     horiz_streak  = 59.132
#     vert_streak   = 62.772
#     diag_smear    = 0.005
#     x_asymmetry   = 0.0823
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)'
# [sim] Artifacts: BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 9.959] cm⁻¹
#   μ_n range : [0.000, 2.196] cm⁻¹
#   Runtime   : 23.5 s
#   Signatures:
#     horiz_streak  = 95.479
#     vert_streak   = 95.027
#     diag_smear    = -0.002
#     x_asymmetry   = 0.0284
#     n_shift       = -0.0013 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Ring artifacts
# (3 bad cols)'
# [sim] Artifacts: BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Ring artifacts
# (3 bad cols)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.937] cm⁻¹
#   μ_n range : [0.000, 2.347] cm⁻¹
#   Runtime   : 15.9 s
#   Signatures:
#     horiz_streak  = 62.862
#     vert_streak   = 65.105
#     diag_smear    = -0.004
#     x_asymmetry   = 0.1065
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Misalignment
# (3 vx, 1°)'
# [sim] Artifacts: BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Misalignment
# (3 vx, 1°)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.937] cm⁻¹
#   μ_n range : [0.000, 2.284] cm⁻¹
#   Runtime   : 21.4 s
#   Signatures:
#     horiz_streak  = 63.335
#     vert_streak   = 65.056
#     diag_smear    = -0.002
#     x_asymmetry   = 0.1064
#     n_shift       = -0.0093 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + misalign'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + misalign' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 11.232] cm⁻¹
#   μ_n range : [0.000, 2.928] cm⁻¹
#   Runtime   : 33.7 s
#   Signatures:
#     horiz_streak  = 104.632
#     vert_streak   = 103.421
#     diag_smear    = 0.160
#     x_asymmetry   = 0.1102
#     n_shift       = 0.0033 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Scatter (n+x) + PSF'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Scatter (n+x) + PSF' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 9.665] cm⁻¹
#   μ_n range : [0.000, 2.156] cm⁻¹
#   Runtime   : 41.0 s
#   Signatures:
#     horiz_streak  = 64.093
#     vert_streak   = 62.229
#     diag_smear    = 0.007
#     x_asymmetry   = 0.0823
#     n_shift       = -0.0613 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + BH + rings'
# [sim] Artifacts: noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + BH + rings' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 11.257] cm⁻¹
#   μ_n range : [0.000, 3.115] cm⁻¹
#   Runtime   : 28.4 s
#   Signatures:
#     horiz_streak  = 108.108
#     vert_streak   = 103.074
#     diag_smear    = 0.244
#     x_asymmetry   = 0.1146
#     n_shift       = 0.0136 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'All realistic'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with FBP …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'All realistic' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 9.962] cm⁻¹
#   μ_n range : [0.000, 2.268] cm⁻¹
#   Runtime   : 58.6 s
#   Signatures:
#     horiz_streak  = 103.012
#     vert_streak   = 103.107
#     diag_smear    = 0.010
#     x_asymmetry   = 0.0925
#     n_shift       = -0.0592 cm⁻¹
#
# [survey] Computing cluster-quality metrics (14 runs)…
#
#   Cluster quality — FBP survey
#   (ranked by Davies-Bouldin index, lower = better)
#   ──────────────────────────────────────────────────────────────
#   Artifact scenario                     DB index  Mean CE [cm⁻¹]
#   ──────────────────────────────────────────────────────────────
#   Detector PSF (σ_x=0.8, σ_n=1.5 px)      0.6400          0.9075
#   Misalignment (3 vx, 1°)                 0.6627          1.0645
#   Clean (reference)                       0.6825          1.1942
#   Beam hardening (no BHC)                 0.6825          1.1942
#   Ring artifacts (3 bad cols)             0.6948          1.1930
#   Scatter (n+x) + PSF                     0.7685          0.7145
#   Noise + BH + rings                      0.7833          1.3051
#   Noise moderate (I₀=5×10⁴)               0.7920          1.2843
#   Noise + misalign                        0.8261          1.2766
#   Beam hardening (BHC corrected)          0.8355          0.7325
#   Noise low dose (I₀=5×10³)               0.8929          0.6586
#   All realistic                           0.9184          0.6101
#   Neutron scatter (f=6%)                  1.0428          1.2720
#   X-ray scatter (f=4%)                    1.0667          1.2338
#   ──────────────────────────────────────────────────────────────
#
#
# === Survey: SIRT ===
# [sim] Loading phantom 'composite' at N=512 …
# [sim] PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
#
# ════════════════════════════════════════════════════════════
#   Artifact survey: 14 runs on 'composite' phantom (N=512)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Clean (reference)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Computing raw sinograms (cached for subsequent runs) …
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Clean (reference)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.509] cm⁻¹
#   μ_n range : [0.000, 2.209] cm⁻¹
#   Runtime   : 77.7 s
#   Signatures:
#     horiz_streak  = 71.474
#     vert_streak   = 75.312
#     diag_smear    = 0.007
#     x_asymmetry   = 0.0639
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise moderate
# (I₀=5×10⁴)'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise moderate
# (I₀=5×10⁴)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.540] cm⁻¹
#   μ_n range : [0.000, 2.259] cm⁻¹
#   Runtime   : 57.4 s
#   Signatures:
#     horiz_streak  = 87.575
#     vert_streak   = 91.463
#     diag_smear    = 0.003
#     x_asymmetry   = 0.0651
#     n_shift       = -0.0001 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise low dose
# (I₀=5×10³)'
# [sim] Artifacts: noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise low dose
# (I₀=5×10³)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.637] cm⁻¹
#   μ_n range : [0.000, 2.440] cm⁻¹
#   Runtime   : 58.8 s
#   Signatures:
#     horiz_streak  = 104.219
#     vert_streak   = 110.409
#     diag_smear    = -0.005
#     x_asymmetry   = 0.0681
#     n_shift       = 0.0019 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (no BHC)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (no BHC)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.509] cm⁻¹
#   μ_n range : [0.000, 2.209] cm⁻¹
#   Runtime   : 45.7 s
#   Signatures:
#     horiz_streak  = 71.474
#     vert_streak   = 75.312
#     diag_smear    = 0.007
#     x_asymmetry   = 0.0639
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (BHC corrected)'
# [sim] Artifacts: BHC(order=3)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (BHC corrected)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BHC(order=3)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.323] cm⁻¹
#   μ_n range : [0.000, 2.209] cm⁻¹
#   Runtime   : 46.8 s
#   Signatures:
#     horiz_streak  = 75.377
#     vert_streak   = 79.435
#     diag_smear    = 0.006
#     x_asymmetry   = 0.0674
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Neutron scatter
# (f=6%)'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Neutron scatter
# (f=6%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.509] cm⁻¹
#   μ_n range : [0.000, 2.170] cm⁻¹
#   Runtime   : 53.1 s
#   Signatures:
#     horiz_streak  = 65.072
#     vert_streak   = 66.597
#     diag_smear    = 0.002
#     x_asymmetry   = 0.0639
#     n_shift       = -0.0304 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'X-ray scatter
# (f=4%)'
# [sim] Artifacts: BH_artifact(no_correction) | x_scatter(f=0.04)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'X-ray scatter
# (f=4%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | x_scatter(f=0.04)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.328] cm⁻¹
#   μ_n range : [0.000, 2.209] cm⁻¹
#   Runtime   : 56.8 s
#   Signatures:
#     horiz_streak  = 68.353
#     vert_streak   = 72.147
#     diag_smear    = 0.008
#     x_asymmetry   = 0.0538
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)'
# [sim] Artifacts: BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.505] cm⁻¹
#   μ_n range : [0.000, 2.207] cm⁻¹
#   Runtime   : 54.0 s
#   Signatures:
#     horiz_streak  = 71.707
#     vert_streak   = 75.597
#     diag_smear    = 0.007
#     x_asymmetry   = 0.0639
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Ring artifacts
# (3 bad cols)'
# [sim] Artifacts: BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Ring artifacts
# (3 bad cols)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.509] cm⁻¹
#   μ_n range : [0.000, 2.216] cm⁻¹
#   Runtime   : 45.8 s
#   Signatures:
#     horiz_streak  = 72.536
#     vert_streak   = 76.414
#     diag_smear    = 0.007
#     x_asymmetry   = 0.0639
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Misalignment
# (3 vx, 1°)'
# [sim] Artifacts: BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Misalignment
# (3 vx, 1°)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.509] cm⁻¹
#   μ_n range : [0.000, 2.209] cm⁻¹
#   Runtime   : 51.6 s
#   Signatures:
#     horiz_streak  = 72.929
#     vert_streak   = 76.582
#     diag_smear    = 0.009
#     x_asymmetry   = 0.0639
#     n_shift       = -0.0079 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + misalign'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + misalign' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.540] cm⁻¹
#   μ_n range : [0.000, 2.259] cm⁻¹
#   Runtime   : 62.8 s
#   Signatures:
#     horiz_streak  = 88.087
#     vert_streak   = 91.925
#     diag_smear    = 0.003
#     x_asymmetry   = 0.0651
#     n_shift       = -0.0066 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Scatter (n+x) + PSF'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Scatter (n+x) + PSF' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.326] cm⁻¹
#   μ_n range : [0.000, 2.169] cm⁻¹
#   Runtime   : 72.0 s
#   Signatures:
#     horiz_streak  = 64.756
#     vert_streak   = 66.341
#     diag_smear    = 0.004
#     x_asymmetry   = 0.0540
#     n_shift       = -0.0304 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + BH + rings'
# [sim] Artifacts: noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + BH + rings' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.556] cm⁻¹
#   μ_n range : [0.000, 2.286] cm⁻¹
#   Runtime   : 57.1 s
#   Signatures:
#     horiz_streak  = 93.202
#     vert_streak   = 97.172
#     diag_smear    = -0.001
#     x_asymmetry   = 0.0658
#     n_shift       = -0.0001 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'All realistic'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SIRT …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'All realistic' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 7.391] cm⁻¹
#   μ_n range : [0.000, 2.189] cm⁻¹
#   Runtime   : 89.0 s
#   Signatures:
#     horiz_streak  = 80.194
#     vert_streak   = 82.048
#     diag_smear    = 0.006
#     x_asymmetry   = 0.0554
#     n_shift       = -0.0325 cm⁻¹
#
# [survey] Computing cluster-quality metrics (14 runs)…
#
#   Cluster quality — SIRT survey
#   (ranked by Davies-Bouldin index, lower = better)
#   ──────────────────────────────────────────────────────────────
#   Artifact scenario                     DB index  Mean CE [cm⁻¹]
#   ──────────────────────────────────────────────────────────────
#   Noise low dose (I₀=5×10³)               0.7180          1.0079
#   All realistic                           0.7592          0.9466
#   Misalignment (3 vx, 1°)                 0.8014          1.0518
#   Scatter (n+x) + PSF                     0.8994          0.6334
#   Clean (reference)                       0.9054          0.5466
#   Beam hardening (no BHC)                 0.9054          0.5466
#   Beam hardening (BHC corrected)          0.9085          0.5626
#   Detector PSF (σ_x=0.8, σ_n=1.5 px)      0.9178          0.5831
#   Ring artifacts (3 bad cols)             0.9212          0.5183
#   Neutron scatter (f=6%)                  0.9321          0.5504
#   Noise + BH + rings                      0.9621          0.9842
#   Noise moderate (I₀=5×10⁴)               0.9866          0.9919
#   Noise + misalign                        1.0040          0.9870
#   X-ray scatter (f=4%)                    1.0348          0.5510
#   ──────────────────────────────────────────────────────────────
#
#
# === Survey: SART ===
# [sim] Loading phantom 'composite' at N=512 …
# [sim] PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
#
# ════════════════════════════════════════════════════════════
#   Artifact survey: 14 runs on 'composite' phantom (N=512)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Clean (reference)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Computing raw sinograms (cached for subsequent runs) …
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Clean (reference)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.530] cm⁻¹
#   μ_n range : [0.000, 2.655] cm⁻¹
#   Runtime   : 54.3 s
#   Signatures:
#     horiz_streak  = 114.575
#     vert_streak   = 110.679
#     diag_smear    = 0.512
#     x_asymmetry   = 0.2034
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise moderate
# (I₀=5×10⁴)'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise moderate
# (I₀=5×10⁴)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.699] cm⁻¹
#   μ_n range : [0.000, 2.712] cm⁻¹
#   Runtime   : 33.5 s
#   Signatures:
#     horiz_streak  = 117.421
#     vert_streak   = 110.487
#     diag_smear    = 0.572
#     x_asymmetry   = 0.2035
#     n_shift       = 0.0007 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise low dose
# (I₀=5×10³)'
# [sim] Artifacts: noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise low dose
# (I₀=5×10³)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.859] cm⁻¹
#   μ_n range : [0.000, 3.115] cm⁻¹
#   Runtime   : 34.3 s
#   Signatures:
#     horiz_streak  = 122.476
#     vert_streak   = 110.368
#     diag_smear    = 0.724
#     x_asymmetry   = 0.2095
#     n_shift       = 0.0079 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (no BHC)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (no BHC)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.536] cm⁻¹
#   μ_n range : [0.000, 2.652] cm⁻¹
#   Runtime   : 22.3 s
#   Signatures:
#     horiz_streak  = 114.593
#     vert_streak   = 110.603
#     diag_smear    = 0.512
#     x_asymmetry   = 0.2044
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (BHC corrected)'
# [sim] Artifacts: BHC(order=3)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (BHC corrected)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BHC(order=3)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.322] cm⁻¹
#   μ_n range : [0.000, 2.640] cm⁻¹
#   Runtime   : 23.4 s
#   Signatures:
#     horiz_streak  = 114.667
#     vert_streak   = 110.504
#     diag_smear    = 0.508
#     x_asymmetry   = 0.2062
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Neutron scatter
# (f=6%)'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Neutron scatter
# (f=6%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.509] cm⁻¹
#   μ_n range : [0.000, 2.516] cm⁻¹
#   Runtime   : 30.0 s
#   Signatures:
#     horiz_streak  = 121.471
#     vert_streak   = 114.546
#     diag_smear    = 0.590
#     x_asymmetry   = 0.2039
#     n_shift       = -0.0380 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'X-ray scatter
# (f=4%)'
# [sim] Artifacts: BH_artifact(no_correction) | x_scatter(f=0.04)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'X-ray scatter
# (f=4%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | x_scatter(f=0.04)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.254] cm⁻¹
#   μ_n range : [0.000, 2.575] cm⁻¹
#   Runtime   : 33.3 s
#   Signatures:
#     horiz_streak  = 116.703
#     vert_streak   = 116.695
#     diag_smear    = 0.438
#     x_asymmetry   = 0.2537
#     n_shift       = -0.0002 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)'
# [sim] Artifacts: BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.462] cm⁻¹
#   μ_n range : [0.000, 2.577] cm⁻¹
#   Runtime   : 30.6 s
#   Signatures:
#     horiz_streak  = 114.264
#     vert_streak   = 110.807
#     diag_smear    = 0.494
#     x_asymmetry   = 0.2002
#     n_shift       = -0.0027 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Ring artifacts
# (3 bad cols)'
# [sim] Artifacts: BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Ring artifacts
# (3 bad cols)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.511] cm⁻¹
#   μ_n range : [0.000, 2.640] cm⁻¹
#   Runtime   : 22.6 s
#   Signatures:
#     horiz_streak  = 114.603
#     vert_streak   = 110.630
#     diag_smear    = 0.513
#     x_asymmetry   = 0.2035
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Misalignment
# (3 vx, 1°)'
# [sim] Artifacts: BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Misalignment
# (3 vx, 1°)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.533] cm⁻¹
#   μ_n range : [0.000, 2.534] cm⁻¹
#   Runtime   : 28.6 s
#   Signatures:
#     horiz_streak  = 97.148
#     vert_streak   = 106.536
#     diag_smear    = 0.447
#     x_asymmetry   = 0.2034
#     n_shift       = -0.0082 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + misalign'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + misalign' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.612] cm⁻¹
#   μ_n range : [0.000, 2.700] cm⁻¹
#   Runtime   : 39.4 s
#   Signatures:
#     horiz_streak  = 117.792
#     vert_streak   = 110.578
#     diag_smear    = 0.590
#     x_asymmetry   = 0.2046
#     n_shift       = -0.0060 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Scatter (n+x) + PSF'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Scatter (n+x) + PSF' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.247] cm⁻¹
#   μ_n range : [0.000, 2.520] cm⁻¹
#   Runtime   : 48.7 s
#   Signatures:
#     horiz_streak  = 123.278
#     vert_streak   = 120.998
#     diag_smear    = 0.518
#     x_asymmetry   = 0.2520
#     n_shift       = -0.0399 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + BH + rings'
# [sim] Artifacts: noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + BH + rings' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.648] cm⁻¹
#   μ_n range : [0.000, 2.739] cm⁻¹
#   Runtime   : 33.7 s
#   Signatures:
#     horiz_streak  = 118.478
#     vert_streak   = 110.474
#     diag_smear    = 0.597
#     x_asymmetry   = 0.2046
#     n_shift       = 0.0012 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'All realistic'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with SART …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'All realistic' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 8.412] cm⁻¹
#   μ_n range : [0.000, 2.504] cm⁻¹
#   Runtime   : 65.4 s
#   Signatures:
#     horiz_streak  = 118.231
#     vert_streak   = 117.955
#     diag_smear    = 0.514
#     x_asymmetry   = 0.1814
#     n_shift       = -0.0406 cm⁻¹
#
# [survey] Computing cluster-quality metrics (14 runs)…
#
#   Cluster quality — SART survey
#   (ranked by Davies-Bouldin index, lower = better)
#   ──────────────────────────────────────────────────────────────
#   Artifact scenario                     DB index  Mean CE [cm⁻¹]
#   ──────────────────────────────────────────────────────────────
#   Noise moderate (I₀=5×10⁴)               0.6908          1.0850
#   All realistic                           0.7056          0.5755
#   Detector PSF (σ_x=0.8, σ_n=1.5 px)      0.7128          1.0716
#   Ring artifacts (3 bad cols)             0.7253          0.9924
#   Beam hardening (no BHC)                 0.7267          0.9941
#   Misalignment (3 vx, 1°)                 0.7433          0.9952
#   Noise + misalign                        0.7585          1.1048
#   Beam hardening (BHC corrected)          0.7812          0.5518
#   X-ray scatter (f=4%)                    0.8433          0.5346
#   Noise low dose (I₀=5×10³)               0.8647          0.7448
#   Scatter (n+x) + PSF                     0.8734          0.5521
#   Noise + BH + rings                      0.9029          0.5892
#   Clean (reference)                       0.9178          0.5650
#   Neutron scatter (f=6%)                  1.0248          0.5533
#   ──────────────────────────────────────────────────────────────
#
#
# === Survey: CGLS ===
# [sim] Loading phantom 'composite' at N=512 …
# [sim] PhantomData('composite', 512³, 0.001953125 cm/voxel, materials=[Air, Al, HDPE, H₂O, Fe, Ti])
#
# ════════════════════════════════════════════════════════════
#   Artifact survey: 14 runs on 'composite' phantom (N=512)
# ════════════════════════════════════════════════════════════
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Clean (reference)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Computing raw sinograms (cached for subsequent runs) …
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Clean (reference)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.162] cm⁻¹
#   μ_n range : [0.000, 2.462] cm⁻¹
#   Runtime   : 81.7 s
#   Signatures:
#     horiz_streak  = 98.837
#     vert_streak   = 101.118
#     diag_smear    = 0.021
#     x_asymmetry   = 0.0975
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise moderate
# (I₀=5×10⁴)'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise moderate
# (I₀=5×10⁴)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.602] cm⁻¹
#   μ_n range : [0.000, 3.560] cm⁻¹
#   Runtime   : 62.2 s
#   Signatures:
#     horiz_streak  = 121.818
#     vert_streak   = 116.870
#     diag_smear    = 0.491
#     x_asymmetry   = 0.1098
#     n_shift       = 0.0250 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise low dose
# (I₀=5×10³)'
# [sim] Artifacts: noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise low dose
# (I₀=5×10³)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+03, I0_n=5e+03) | BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 13.890] cm⁻¹
#   μ_n range : [0.000, 6.137] cm⁻¹
#   Runtime   : 63.4 s
#   Signatures:
#     horiz_streak  = 128.018
#     vert_streak   = 111.210
#     diag_smear    = 0.902
#     x_asymmetry   = 0.1946
#     n_shift       = 0.0895 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (no BHC)'
# [sim] Artifacts: BH_artifact(no_correction)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (no BHC)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.162] cm⁻¹
#   μ_n range : [0.000, 2.462] cm⁻¹
#   Runtime   : 49.7 s
#   Signatures:
#     horiz_streak  = 98.837
#     vert_streak   = 101.118
#     diag_smear    = 0.021
#     x_asymmetry   = 0.0975
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Beam hardening
# (BHC corrected)'
# [sim] Artifacts: BHC(order=3)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Beam hardening
# (BHC corrected)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BHC(order=3)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 11.967] cm⁻¹
#   μ_n range : [0.000, 2.462] cm⁻¹
#   Runtime   : 50.9 s
#   Signatures:
#     horiz_streak  = 98.287
#     vert_streak   = 100.543
#     diag_smear    = 0.019
#     x_asymmetry   = 0.0994
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Neutron scatter
# (f=6%)'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Neutron scatter
# (f=6%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.162] cm⁻¹
#   μ_n range : [0.000, 2.360] cm⁻¹
#   Runtime   : 57.2 s
#   Signatures:
#     horiz_streak  = 106.033
#     vert_streak   = 106.825
#     diag_smear    = 0.045
#     x_asymmetry   = 0.0975
#     n_shift       = -0.0268 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'X-ray scatter
# (f=4%)'
# [sim] Artifacts: BH_artifact(no_correction) | x_scatter(f=0.04)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'X-ray scatter
# (f=4%)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | x_scatter(f=0.04)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 11.796] cm⁻¹
#   μ_n range : [0.000, 2.462] cm⁻¹
#   Runtime   : 60.6 s
#   Signatures:
#     horiz_streak  = 96.997
#     vert_streak   = 99.316
#     diag_smear    = 0.045
#     x_asymmetry   = 0.0785
#     n_shift       = 0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)'
# [sim] Artifacts: BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Detector PSF
# (σ_x=0.8, σ_n=1.5 px)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.339] cm⁻¹
#   μ_n range : [0.000, 2.199] cm⁻¹
#   Runtime   : 57.7 s
#   Signatures:
#     horiz_streak  = 66.552
#     vert_streak   = 66.570
#     diag_smear    = -0.008
#     x_asymmetry   = 0.0264
#     n_shift       = -0.0028 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Ring artifacts
# (3 bad cols)'
# [sim] Artifacts: BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Ring artifacts
# (3 bad cols)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.162] cm⁻¹
#   μ_n range : [0.000, 2.462] cm⁻¹
#   Runtime   : 49.9 s
#   Signatures:
#     horiz_streak  = 99.676
#     vert_streak   = 101.945
#     diag_smear    = 0.021
#     x_asymmetry   = 0.0975
#     n_shift       = -0.0000 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Misalignment
# (3 vx, 1°)'
# [sim] Artifacts: BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Misalignment
# (3 vx, 1°)' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 1.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.162] cm⁻¹
#   μ_n range : [0.000, 2.457] cm⁻¹
#   Runtime   : 55.7 s
#   Signatures:
#     horiz_streak  = 96.620
#     vert_streak   = 98.004
#     diag_smear    = 0.019
#     x_asymmetry   = 0.0974
#     n_shift       = -0.0075 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + misalign'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + misalign' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=5e+04) | BH_artifact(no_correction) | misalign(T=(3.0, 0.0, 0.0),R=(0.0, 0.0, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.602] cm⁻¹
#   μ_n range : [0.000, 3.560] cm⁻¹
#   Runtime   : 67.7 s
#   Signatures:
#     horiz_streak  = 121.994
#     vert_streak   = 116.866
#     diag_smear    = 0.497
#     x_asymmetry   = 0.1098
#     n_shift       = 0.0185 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Scatter (n+x) + PSF'
# [sim] Artifacts: BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Scatter (n+x) + PSF' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : BH_artifact(no_correction) | n_scatter(f=0.06) | x_scatter(f=0.04) | PSF(σ_x=0.8,σ_n=1.5)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.035] cm⁻¹
#   μ_n range : [0.000, 2.160] cm⁻¹
#   Runtime   : 75.6 s
#   Signatures:
#     horiz_streak  = 77.634
#     vert_streak   = 79.033
#     diag_smear    = 0.033
#     x_asymmetry   = 0.0817
#     n_shift       = -0.0274 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'Noise + BH + rings'
# [sim] Artifacts: noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'Noise + BH + rings' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=3e+04, I0_n=3e+04) | BH_artifact(no_correction) | rings(N=3,amp=0.05)
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 12.685] cm⁻¹
#   μ_n range : [0.000, 3.866] cm⁻¹
#   Runtime   : 62.1 s
#   Signatures:
#     horiz_streak  = 123.667
#     vert_streak   = 114.860
#     diag_smear    = 0.634
#     x_asymmetry   = 0.1194
#     n_shift       = 0.0335 cm⁻¹
#
# ────────────────────────────────────────────────────────────
# [sim] Run: 'All realistic'
# [sim] Artifacts: noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
# [sim] Injecting sinogram artifacts …
# [sim] Reconstructing …
# [reconstructor] Reconstructing with CGLS …
#   -> X-ray …
#   -> Neutron …
# [reconstructor] Done.
# [sim] Injecting volume artifacts …
# [sim] Computing bimodal histogram …
# ═══ SimulationResult: 'All realistic' ═══
#   Phantom   : composite  (512³ voxels)
#   Artifacts : noise(I0_x=5e+04, I0_n=3e+04) | BH_artifact(no_correction) | n_scatter(f=0.05) | x_scatter(f=0.03) | PSF(σ_x=0.7,σ_n=1.4) | rings(N=2,amp=0.04) | misalign(T=(2.0, 0.5, 0.0),R=(0.0, 0.8, 0.0))
#   Vol shape : (512, 512, 512)
#   μ_x range : [0.000, 10.426] cm⁻¹
#   μ_n range : [0.000, 2.285] cm⁻¹
#   Runtime   : 93.0 s
#   Signatures:
#     horiz_streak  = 115.127
#     vert_streak   = 115.604
#     diag_smear    = 0.054
#     x_asymmetry   = 0.0926
#     n_shift       = -0.0294 cm⁻¹
#
# [survey] Computing cluster-quality metrics (14 runs)…
#
#   Cluster quality — CGLS survey
#   (ranked by Davies-Bouldin index, lower = better)
#   ──────────────────────────────────────────────────────────────
#   Artifact scenario                     DB index  Mean CE [cm⁻¹]
#   ──────────────────────────────────────────────────────────────
#   All realistic                           0.6590          0.9173
#   X-ray scatter (f=4%)                    0.6811          1.0141
#   Detector PSF (σ_x=0.8, σ_n=1.5 px)      0.8007          0.6962
#   Neutron scatter (f=6%)                  0.8246          1.0849
#   Misalignment (3 vx, 1°)                 0.8895          0.9753
#   Noise low dose (I₀=5×10³)               1.0968          1.0760
#   Beam hardening (BHC corrected)          1.1190          1.1939
#   Scatter (n+x) + PSF                     1.1220          0.8931
#   Noise + BH + rings                      1.3275          1.0136
#   Noise moderate (I₀=5×10⁴)               1.3534          1.1554
#   Noise + misalign                        1.4082          1.1724
#   Clean (reference)                       1.9334          1.0772
#   Beam hardening (no BHC)                 1.9334          1.0772
#   Ring artifacts (3 bad cols)             2.3177          1.0724
#   ──────────────────────────────────────────────────────────────
#
#
# All surveys complete.
# {'ok': True,
#  'result': {'message_id': 2379,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776357996,
#   'text': 'All surveys complete.'}}

# %%
# ── Side-by-side clean-run DB / CE rankings ───────────────────────────────
print(f"\n{'Algorithm':<14}  {'DB (clean)':>12}  {'Mean CE (clean)':>16}")
send_message(f"\n{'Algorithm':<14}  {'DB (clean)':>12}  {'Mean CE (clean)':>16}")
print('─' * 48)
for alg, d in clean_results_by_alg.items():
    m = d['metrics']
    if m:
        print(f"{alg:<14}  {m.davies_bouldin:>12.4f}  {m.mean_centroid_error:>16.4f}")
        send_message(f"{alg:<14}  {m.davies_bouldin:>12.4f}  {m.mean_centroid_error:>16.4f}")
send_message("Metrics done.")
# Out:
# Algorithm         DB (clean)   Mean CE (clean)
# ────────────────────────────────────────────────
# FBP                   0.6825            1.1942
# SIRT                  0.9054            0.5466
# SART                  0.9178            0.5650
# CGLS                  1.9334            1.0772
# {'ok': True,
#  'result': {'message_id': 2385,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776357997,
#   'text': 'Metrics done.'}}

# %% [markdown]
# ---
# ## 12 · Cross-Algorithm Bimodal Histogram Grid  ★ new in v3

# %% [markdown]
# What happens when you use **FBP for X-ray** but **SIRT for neutron** —
# or vice versa? The `plot_cross_algorithm_grid` function reconstructs
# each modality independently and builds H(μ_x, μ_n) from the pair.
#
# This reveals which modality's reconstruction algorithm drives cluster quality.
#
# **Design:**
# - `make_cross_algorithm_sinos` runs the forward projection **once** and
#   returns a shared sinogram dict for all algorithms.
# - Each panel reconstructs the X-ray channel with `alg_x` and the neutron
#   channel with `alg_n` independently.
# - Reconstruction results are cached in memory — if FBP appears in multiple
#   panels, it is only run once per modality.

# %%
import os; os.makedirs('output_grids', exist_ok=True)

# ── Algorithms to compare in the grid ─────────────────────────────────────
GRID_ALGORITHMS = ['FBP', 'SIRT', 'SART', 'CGLS']
send_message("Starting cross-algorithm simulation")

# ── Generate sinograms once for all panels ─────────────────────────────────
x_sinos, n_sinos = make_cross_algorithm_sinos(
    phantom        = phantom,
    algorithms     = GRID_ALGORITHMS,
    n_angles       = N_ANGLES,
    kVp            = KVP,
    filter_mm_Al   = AL_FILTER,
    use_astra      = True,
    cfg            = None,   # clean; pass ArtifactConfig(...) for artifacts
)
print('Sinograms ready. Starting grid reconstruction...')
send_message("Sinograms prepared for the cross-algorithm simulation.")
# Out:
# [projector] Projecting 600 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# Sinograms ready. Starting grid reconstruction...
# {'ok': True,
#  'result': {'message_id': 2387,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776358030,
#   'text': 'Sinograms prepared for the cross-algorithm simulation.'}}

# %%
# ── Diagonal comparison: same algorithm for both modalities ───────────────
diagonal_pairs = [(alg, alg) for alg in GRID_ALGORITHMS]

fig_diag, hists_diag = plot_cross_algorithm_grid(
    phantom         = phantom,
    xray_sinos      = x_sinos,
    neutron_sinos   = n_sinos,
    algorithm_pairs = diagonal_pairs,
    show_marginals  = True,
    show_gt_markers = True,
    show_metrics    = True,
    ncols           = 2,
    suptitle        = f'Diagonal comparison — same algorithm for both modalities ({PRESET})',
)
fig_diag.savefig('output_grids/cross_alg_diagonal.png',
                 dpi=150, bbox_inches='tight')
plt.show()
print('Saved output_grids/cross_alg_diagonal.png')
send_message("Diagonal pairs completed.")
send_image('output_grids/cross_alg_diagonal.png')
# Out:
# Saved output_grids/cross_alg_diagonal.png
# {'ok': True,
#  'result': {'message_id': 2389,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776358475,
#   'photo': [{'file_id': 'AgACAgQAAxkDAAIJVWnhFEq_5NWylJCVZTSNeV0H-7WKAAIhDWsbZ-oIU4IGZLZBJuDlAQADAgADcwADOwQ',
#     'file_unique_id': 'AQADIQ1rG2fqCFN4',
#     'file_size': 2135,
#     'width': 90,
#     'height': 83},
#    {'file_id': 'AgACAgQAAxkDAAIJVWnhFEq_5NWylJCVZTSNeV0H-7WKAAIhDWsbZ-oIU4IGZLZBJuDlAQADAgADbQADOwQ',
#     'file_unique_id': 'AQADIQ1rG2fqCFNy',
#     'file_size': 28922,
#     'width': 320,
#     'height': 296},
#    {'file_id': 'AgACAgQAAxkDAAIJVWnhFEq_5NWylJCVZTSNeV0H-7WKAAIhDWsbZ-oIU4IGZLZBJuDlAQADAgADeAADOwQ',
#     'file_unique_id': 'AQADIQ1rG2fqCFN9',
#     'file_size': 110709,
#     'width': 800,
#     'height': 739},
#    {'file_id': 'AgACAgQAAxkDAAIJVWnhFEq_5NWylJCVZTSNeV0H-7WKAAIhDWsbZ-oIU4IGZLZBJuDlAQADAgADeQADOwQ',
#     'file_unique_id': 'AQADIQ1rG2fqCFN-',
#     'file_size': 207630,
#     'width': 1280,
#     'height': 1183},
#    {'file_id': 'AgACAgQAAxkDAAIJVWnhFEq_5NWylJCVZTSNeV0H-7WKAAIhDWsbZ-oIU4IGZLZBJuDlAQADAgADdwADOwQ',
#     'file_unique_id': 'AQADIQ1rG2fqCFN8',
#     'file_size': 250651,
#     'width': 1577,
#     'height': 1457}]}}

# %%
# ── Full factorial 4×4 grid ────────────────────────────────────────────────
# Rows = X-ray algorithm, Columns = neutron algorithm.
full_pairs = [(ax, an) for ax in GRID_ALGORITHMS for an in GRID_ALGORITHMS]

fig_full, hists_full = plot_cross_algorithm_grid(
    phantom         = phantom,
    xray_sinos      = x_sinos,
    neutron_sinos   = n_sinos,
    algorithm_pairs = full_pairs,
    show_marginals  = False,   # compact layout for 4×4
    show_gt_markers = True,
    show_metrics    = True,
    ncols           = len(GRID_ALGORITHMS),
    figsize_per_panel = (4.2, 3.8),
    suptitle        = f'Full {len(GRID_ALGORITHMS)}×{len(GRID_ALGORITHMS)} algorithm grid — {PRESET} phantom (clean)',
)
fig_full.savefig('output_grids/cross_alg_full_grid.png',
                 dpi=150, bbox_inches='tight')
plt.show()
print('Saved output_grids/cross_alg_full_grid.png')
send_message("Full grid cross-algorithm calculation done.")
send_image('output_grids/cross_alg_full_grid.png')
# Out:
# Saved output_grids/cross_alg_full_grid.png
# {'ok': True,
#  'result': {'message_id': 2391,
#   'from': {'id': 1858240996,
#    'is_bot': True,
#    'first_name': 'NICHE',
#    'username': 'niche_zwo_bot'},
#   'chat': {'id': 6133696,
#    'first_name': 'Oriol',
#    'last_name': 'Sans Planell',
#    'username': 'Oriol_Sans_Planell',
#    'type': 'private'},
#   'date': 1776359950,
#   'photo': [{'file_id': 'AgACAgQAAxkDAAIJV2nhGg0tVC_G4WcNTuIkBXm7HYkyAAInDWsbZ-oIU07g6Vxrmdx1AQADAgADcwADOwQ',
#     'file_unique_id': 'AQADJw1rG2fqCFN4',
#     'file_size': 2391,
#     'width': 90,
#     'height': 82},
#    {'file_id': 'AgACAgQAAxkDAAIJV2nhGg0tVC_G4WcNTuIkBXm7HYkyAAInDWsbZ-oIU07g6Vxrmdx1AQADAgADbQADOwQ',
#     'file_unique_id': 'AQADJw1rG2fqCFNy',
#     'file_size': 38050,
#     'width': 320,
#     'height': 290},
#    {'file_id': 'AgACAgQAAxkDAAIJV2nhGg0tVC_G4WcNTuIkBXm7HYkyAAInDWsbZ-oIU07g6Vxrmdx1AQADAgADeAADOwQ',
#     'file_unique_id': 'AQADJw1rG2fqCFN9',
#     'file_size': 152543,
#     'width': 800,
#     'height': 724},
#    {'file_id': 'AgACAgQAAxkDAAIJV2nhGg0tVC_G4WcNTuIkBXm7HYkyAAInDWsbZ-oIU07g6Vxrmdx1AQADAgADeQADOwQ',
#     'file_unique_id': 'AQADJw1rG2fqCFN-',
#     'file_size': 309193,
#     'width': 1280,
#     'height': 1159},
#    {'file_id': 'AgACAgQAAxkDAAIJV2nhGg0tVC_G4WcNTuIkBXm7HYkyAAInDWsbZ-oIU07g6Vxrmdx1AQADAgADdwADOwQ',
#     'file_unique_id': 'AQADJw1rG2fqCFN8',
#     'file_size': 712862,
#     'width': 2537,
#     'height': 2297}]}}

# %%
# ── Custom selection: mixed pairs of interest ──────────────────────────────
custom_pairs = [
    ('FBP',  'FBP'),    # baseline analytic
    ('FBP',  'SIRT'),   # weak X-ray, strong neutron
    ('SIRT', 'FBP'),    # strong X-ray, weak neutron
    ('SIRT', 'SIRT'),   # both iterative
    ('SART', 'SART'),   # recommended pair
    ('SART', 'SIRT'),   # SART X-ray + SIRT neutron (SIRT sharper for H₂O/HDPE)
]

fig_custom, hists_custom = plot_cross_algorithm_grid(
    phantom         = phantom,
    xray_sinos      = x_sinos,
    neutron_sinos   = n_sinos,
    algorithm_pairs = custom_pairs,
    show_marginals  = True,
    show_metrics    = True,
    ncols           = 3,
    suptitle        = 'Selected cross-algorithm combinations — clean acquisition',
)
fig_custom.savefig('output_grids/cross_alg_custom.png',
                   dpi=150, bbox_inches='tight')
plt.show()
print('Saved output_grids/cross_alg_custom.png')

# %%
# ── Repeat with artifacts injected ────────────────────────────────────────
noise_cfg = nxs.ArtifactConfig(photon_noise=True, I0_xray=5e4, I0_neutron=5e4)
x_sinos_noise, n_sinos_noise = make_cross_algorithm_sinos(
    phantom, GRID_ALGORITHMS, n_angles=N_ANGLES, cfg=noise_cfg,
)

fig_noise, _ = plot_cross_algorithm_grid(
    phantom, x_sinos_noise, n_sinos_noise, diagonal_pairs,
    show_metrics=True, ncols=2,
    suptitle='Diagonal comparison — moderate Poisson noise (I₀=5×10⁴)',
)
fig_noise.savefig('output_grids/cross_alg_noisy.png',
                  dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## 13 · Cluster Quality Metrics & Algorithm Ranking  ★ new in v3

# %% [markdown]
# Three complementary metrics quantify bimodal histogram quality against
# known ground-truth material positions.
#
# | Metric | Symbol | Meaning | Better |
# |--------|--------|---------|--------|
# | Centroid error | CE_k | Distance of GMM centroid from GT position [cm⁻¹] | lower |
# | Cluster spread | σ_x, σ_n | Std of cluster along each axis [cm⁻¹] | lower |
# | Davies-Bouldin | DB | Separability index (compactness ÷ separation) | lower |
#
# **`evaluate_histogram_quality(hist, phantom)`** returns all three.
# **`compare_algorithms(results, phantom)`** tabulates them across a list
# of `SimulationResult` objects.

# %%
# ── Per-panel metrics for the cross-algorithm grid ─────────────────────────
print(f"\n{'X-ray alg':<10}  {'Neutron alg':<12}  {'DB':>8}  {'Mean CE [cm⁻¹]':>16}")
print('─' * 56)
grid_metric_rows = []
for (alg_x, alg_n), hist in hists_full.items():
    m = evaluate_histogram_quality(hist, phantom)
    print(f"{alg_x:<10}  {alg_n:<12}  {m.davies_bouldin:>8.4f}  {m.mean_centroid_error:>16.4f}")
    grid_metric_rows.append({'alg_x': alg_x, 'alg_n': alg_n,
                              'db': m.davies_bouldin,
                              'ce': m.mean_centroid_error})
    send_message(f"{alg_x:<10}  {alg_n:<12}  {m.davies_bouldin:>8.4f}  {m.mean_centroid_error:>16.4f}")
send_message("metrics finished. RUN COMPLETE")

# %%
# ── Heat-map of DB index across the algorithm grid ────────────────────────
import numpy as _np

n_alg = len(GRID_ALGORITHMS)
db_mat = _np.full((n_alg, n_alg), float('nan'))
ce_mat = _np.full((n_alg, n_alg), float('nan'))
for row in grid_metric_rows:
    i = GRID_ALGORITHMS.index(row['alg_x'])
    j = GRID_ALGORITHMS.index(row['alg_n'])
    db_mat[i, j] = row['db']
    ce_mat[i, j] = row['ce']

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
for ax, mat, title, fmt in [
        (axes[0], db_mat, 'Davies-Bouldin index\n(lower = better)', '.3f'),
        (axes[1], ce_mat, 'Mean centroid error [cm⁻¹]\n(lower = better)', '.4f'),
]:
    im = ax.imshow(mat, cmap='RdYlGn_r', aspect='auto')
    ax.set_xticks(range(n_alg)); ax.set_xticklabels(GRID_ALGORITHMS)
    ax.set_yticks(range(n_alg)); ax.set_yticklabels(GRID_ALGORITHMS)
    ax.set_xlabel('Neutron algorithm'); ax.set_ylabel('X-ray algorithm')
    ax.set_title(title)
    plt.colorbar(im, ax=ax)
    for i in range(n_alg):
        for j in range(n_alg):
            if not _np.isnan(mat[i, j]):
                ax.text(j, i, format(mat[i, j], fmt),
                        ha='center', va='center', fontsize=8,
                        color='white' if mat[i, j] > mat.max()*0.6 else 'black')
plt.tight_layout()
plt.savefig('output_grids/metric_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()
print('Saved output_grids/metric_heatmap.png')

# %%
# ── compare_algorithms on the orchestrator results ─────────────────────────
# Run the clean scenario with four algorithms and compare in one table.

comparison_results = []
for alg in GRID_ALGORITHMS:
    sim_cmp = nxs.DualModalitySimulation(
        preset=PRESET, N=N, n_angles=N_ANGLES,
        algorithm=alg, verbose=False,
    )
    r = sim_cmp.run(nxs.ArtifactConfig.clean(), tag=alg)
    comparison_results.append(r)

metrics_cmp = compare_algorithms(
    comparison_results, phantom=phantom, print_table=True
)

# %%
# ── Per-material centroid errors for the best and worst algorithm ──────────
best_alg  = min(metrics_cmp, key=lambda k: metrics_cmp[k].davies_bouldin)
worst_alg = max(metrics_cmp, key=lambda k: metrics_cmp[k].davies_bouldin)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, alg in zip(axes, [best_alg, worst_alg]):
    m    = metrics_cmp[alg]
    mats = list(m.centroid_errors.keys())
    errs = [m.centroid_errors[mat] for mat in mats]
    sx   = [m.sigma_x.get(mat, 0) for mat in mats]
    sn   = [m.sigma_n.get(mat, 0) for mat in mats]
    x    = range(len(mats))
    ax.bar(x, errs, color='steelblue', alpha=0.8, label='Centroid error')
    ax.errorbar(x, errs, yerr=[sx, sn], fmt='none', color='black',
                capsize=4, lw=1.5, label='σ_x / σ_n')
    ax.set_xticks(list(x)); ax.set_xticklabels(mats, rotation=30, ha='right')
    ax.set_ylabel('cm⁻¹'); ax.set_title(f'{alg}  (DB={m.davies_bouldin:.3f})')
    ax.legend(); ax.grid(True, alpha=0.3)
fig.suptitle('Per-material centroid errors: best vs worst algorithm', fontsize=11)
plt.tight_layout()
plt.savefig('output_grids/centroid_errors.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ---
# ## 14 · Save Figures

# %%
import os
os.makedirs('output_figures', exist_ok=True)

save_map = [
    ('output_figures/comparison_grid.png',  sim.comparison_grid(all_results, ncols=3)),
    ('output_figures/slices_realistic.png',  r_real.plot_slices()),
    ('output_figures/histogram_realistic.png', r_real.plot_histogram(show_marginals=True)),
]

for path, fig_obj in save_map:
    fig_obj.savefig(path, dpi=150, bbox_inches='tight')
    plt.close(fig_obj)
    print(f'Saved {path}')

# %%
# ── Save numpy arrays ─────────────────────────────────────────────────────
os.makedirs('output_volumes', exist_ok=True)

for tag, r in [('clean', r_clean), ('noise', r_noise),
                ('scatter', r_scatter), ('realistic', r_real)]:
    np.save(f'output_volumes/vol_xray_{tag}.npy',    r.vol_xray)
    np.save(f'output_volumes/vol_neutron_{tag}.npy', r.vol_neutron)
    print(f'Saved vol_xray_{tag}.npy + vol_neutron_{tag}.npy')

print('\nAll outputs saved.')

# %%
 
import gc
import json
import time
import ctypes
import platform
import warnings
from pathlib import Path
 
import numpy as np
 
try:
    import psutil as _psutil
    _PSUTIL = True
except ImportError:
    _PSUTIL = False
    warnings.warn(
        "psutil not found — RAM monitoring disabled.  "
        "Install with:  pip install psutil"
    )
 
import neutron_xray_sim as nxs
from neutron_xray_sim.artifacts import (
    inject_sinogram_artifacts,
    inject_volume_artifacts,
)
 
 
# ─────────────────────────────────────────────────────────────────────────────
# Memory utilities
# ─────────────────────────────────────────────────────────────────────────────
 
def _ram_mb():
    if not _PSUTIL:
        return 0.0
    return _psutil.Process().memory_info().rss / 1e6
 
def _system_ram_pct():
    if not _PSUTIL:
        return 0.0
    return _psutil.virtual_memory().percent
 
def _system_ram_available_gb():
    if not _PSUTIL:
        return float("nan")
    return _psutil.virtual_memory().available / 1e9
 
def _free_ram():
    """
    Force Python to release memory back to the OS.
 
    Runs three GC generations, then calls:
    - Linux : malloc_trim(0) — returns freed glibc heap pages to the kernel
              immediately, rather than waiting for the next large allocation.
    - Windows: HeapCompact (best-effort; Windows already returns most memory
              promptly when large allocations are freed).
 
    Call this after every explicit del of a large array.
    """
    gc.collect(0)
    gc.collect(1)
    gc.collect(2)
    if platform.system() == "Linux":
        try:
            ctypes.CDLL("libc.so.6").malloc_trim(0)
        except Exception:
            pass
    elif platform.system() == "Windows":
        try:
            ctypes.windll.kernel32.HeapCompact(0, 0)
        except Exception:
            pass
 
def _astra_clear():
    """
    Release all ASTRA GPU objects (data arrays, algorithms, projectors).
 
    ASTRA keeps a global registry; if a previous run crashed mid-slice,
    orphaned GPU buffers remain allocated.  Calling this before each
    reconstruction ensures a clean GPU state and prevents VRAM leaks.
    """
    try:
        import astra
        astra.data2d.clear()
        astra.data3d.clear()
        astra.algorithm.clear()
        astra.projector.clear()
    except Exception:
        pass
 
 
# ─────────────────────────────────────────────────────────────────────────────
# Main batch function
# ─────────────────────────────────────────────────────────────────────────────
 
def batch_reconstruct_all(
    output_dir       = "batch_1024",
    phantoms         = None,
    algorithms       = None,
    artifacts        = None,
    N                = 1024,
    n_angles         = 1200,
    kVp              = 120.0,
    filter_mm_Al     = 2.0,
    n_iter           = 30,
    n_subsets        = 10,
    lambda_tv        = 0.02,
    filter_name      = "shepp-logan",
    remove_rings     = True,
    ram_warn_gb      = 300.0,
    ram_abort_gb     = None,
    use_astra        = True,
    overwrite        = False,
    rng_seed         = 0,
):
    """
    Run every combination of phantom x artifact x algorithm for X-ray
    and neutron, saving reconstructed volumes as .npy files.
 
    Memory design
    -------------
    - Sinogram computed ONCE per (phantom, artifact), reused for all algorithms.
    - Raw sinogram copies deleted immediately after artifact injection.
    - Both modalities reconstructed together then inject_volume_artifacts called
      once with REAL volumes (no dummy arrays).
    - Explicit del + _free_ram() after every large temporary array.
    - ASTRA GPU objects cleared before every reconstruction call.
    - RAM monitored after every algorithm step via psutil.
 
    Parameters
    ----------
    output_dir    : root output directory
    phantoms      : list of preset names, or None = all four
    algorithms    : list of algorithm names, or None = all nine
    artifacts     : list of (label, kwargs) or None = default 11
    N             : voxel grid N x N x N
    n_angles      : projection angles
    kVp           : X-ray tube voltage [kV]
    filter_mm_Al  : Al pre-filter [mm]
    n_iter        : iterations for iterative algorithms
    n_subsets     : ordered subsets for OSSART
    lambda_tv     : TV weight for TV_MIN
    filter_name   : ramp filter for FBP/GRIDREC
    remove_rings  : Vo ring removal pre-processing
    ram_warn_gb   : warn when process RAM exceeds this [GB]
    ram_abort_gb  : raise MemoryError if RAM exceeds this [GB] (None=off)
    use_astra     : use ASTRA GPU
    overwrite     : skip existing volumes if False
    rng_seed      : reproducibility seed
 
    Returns
    -------
    manifest : list of dicts with keys
        phantom, artifact, algorithm, modality,
        path, shape, ram_mb_after, elapsed_s, skipped
    """
 
    # ── Defaults ──────────────────────────────────────────────────────────────
    if phantoms is None:
        phantoms = ["composite", "battery", "bone_implant", "industrial"]
 
    if algorithms is None:
        algorithms = list(nxs.AVAILABLE_ALGORITHMS)
 
    if artifacts is None:
        artifacts = [
            ("clean",
             {}),
            ("noise_moderate",
             dict(photon_noise=True, I0_xray=5e4, I0_neutron=5e4)),
            ("noise_low_dose",
             dict(photon_noise=True, I0_xray=5e3, I0_neutron=5e3)),
            ("beam_hardening",
             dict(apply_bh_correction=False)),
            ("bh_corrected",
             dict(apply_bh_correction=True, bh_correction_order=3)),
            ("neutron_scatter",
             dict(neutron_scatter=True, scatter_fraction=0.06,
                  scatter_sigma_pixels=9.0)),
            ("xray_scatter",
             dict(xray_scatter=True, xray_scatter_fraction=0.04)),
            ("detector_psf",
             dict(detector_psf=True,
                  psf_sigma_xray_pixels=0.8,
                  psf_sigma_neutron_pixels=1.5)),
            ("ring_artifacts",
             dict(ring_artifacts=True, n_bad_columns=3,
                  ring_amplitude=0.05)),
            ("misalignment",
             dict(misalignment=True,
                  translation_voxels=(3.0, 0.0, 0.0),
                  rotation_deg=(0.0, 1.0, 0.0))),
            ("all_realistic",
             dict(photon_noise=True,    I0_xray=5e4,   I0_neutron=5e4,
                  neutron_scatter=True, scatter_fraction=0.06,
                  xray_scatter=True,    xray_scatter_fraction=0.04,
                  detector_psf=True,
                  psf_sigma_xray_pixels=0.8,
                  psf_sigma_neutron_pixels=1.5,
                  misalignment=True,
                  translation_voxels=(3.0, 0.0, 0.0))),
        ]
 
    root = Path(output_dir)
    root.mkdir(parents=True, exist_ok=True)
    rng  = np.random.default_rng(rng_seed)
 
    total_pairs  = len(phantoms) * len(artifacts) * len(algorithms)
    total_vols   = total_pairs * 2
    done_pairs   = 0
    manifest     = []
    t_global     = time.perf_counter()
    vol_mb       = (N ** 3 * 4) / 1e6
 
    # ── Header ────────────────────────────────────────────────────────────────
    print("=" * 76)
    print("  Memory-efficient batch reconstruction")
    print(f"  Phantoms   : {phantoms}")
    print(f"  Algorithms : {algorithms}")
    print(f"  Artifacts  : {[a[0] for a in artifacts]}")
    print(f"  N={N}  angles={n_angles}  iter={n_iter}  overwrite={overwrite}")
    print(f"  Volume     : {vol_mb:.1f} MB each  |  "
          f"Max simultaneous: 2 volumes = {2*vol_mb:.0f} MB")
    print(f"  Total      : {total_vols} volumes  "
          f"({total_vols*vol_mb/1e3:.1f} GB if kept — we keep 2)")
    
    send_message("  Memory-efficient batch reconstruction")
    send_message(f"  Phantoms   : {phantoms}")
    send_message(f"  Algorithms : {algorithms}")
    send_message(f"  Artifacts  : {[a[0] for a in artifacts]}")
    send_message(f"  N={N}  angles={n_angles}  iter={n_iter}  overwrite={overwrite}")
    send_message(f"  Volume     : {vol_mb:.1f} MB each  |  "
          f"Max simultaneous: 2 volumes = {2*vol_mb:.0f} MB")
    send_message(f"  Total      : {total_vols} volumes  "
          f"({total_vols*vol_mb/1e3:.1f} GB if kept — we keep 2)")
    if _PSUTIL:
        vm = _psutil.virtual_memory()
        print(f"  System RAM : {vm.total/1e9:.1f} GB total  |  "
              f"{vm.available/1e9:.1f} GB available now")
        print(f"  RAM warn={ram_warn_gb} GB"
              + (f"  abort={ram_abort_gb} GB" if ram_abort_gb else "  abort=off"))
        send_message(f"  System RAM : {vm.total/1e9:.1f} GB total  |  "
              f"{vm.available/1e9:.1f} GB available now")
        send_message(f"  RAM warn={ram_warn_gb} GB"
              + (f"  abort={ram_abort_gb} GB" if ram_abort_gb else "  abort=off"))
    else:
        print("  RAM monitoring: disabled (pip install psutil)")
    print("=" * 76)
 
    def _check_ram(label):
        rss_mb   = _ram_mb()
        rss_gb   = rss_mb / 1e3
        avail_gb = _system_ram_available_gb()
        sys_pct  = _system_ram_pct()
        if _PSUTIL:
            line = (f"  RAM  proc={rss_gb:.2f} GB  "
                    f"sys={sys_pct:.0f}%  avail={avail_gb:.1f} GB  [{label}]")
            if rss_gb > ram_warn_gb:
                print("  WARNING " + line)
                send_message("  WARNING " + line)
            else:
                print("        " + line)
                send_message("        " + line)
            if ram_abort_gb and rss_gb > ram_abort_gb:
                raise MemoryError(
                    f"Process RAM {rss_gb:.2f} GB > abort threshold "
                    f"{ram_abort_gb} GB at [{label}]."
                )
                send_message(f"Process RAM {rss_gb:.2f} GB > abort threshold "
                    f"{ram_abort_gb} GB at [{label}].")
        return rss_mb
 
    # ═════════════════════════════════════════════════════════════════════════
    # Phantom loop
    # ═════════════════════════════════════════════════════════════════════════
    for ph_name in phantoms:
 
        print(f"\n{'─'*76}")
        print(f"  [Phantom] {ph_name}  N={N}")
        send_message(f"  [Phantom] {ph_name}  N={N}")
        _free_ram()
        phantom = nxs.make_phantom(ph_name, N)
        (root / ph_name).mkdir(exist_ok=True)
 
        # ── Artifact loop ─────────────────────────────────────────────────────
        for art_label, art_kwargs in artifacts:
 
            art_dir = root / ph_name / art_label
            art_dir.mkdir(exist_ok=True)
            cfg = nxs.ArtifactConfig(**art_kwargs)
 
            sino_x_path = art_dir / "raw_xray_sino.npy"
            sino_n_path = art_dir / "raw_neutron_sino.npy"
            ang_path    = art_dir / "angles_deg.npy"
            vcm_path    = art_dir / "voxel_cm.txt"
 
            if sino_x_path.exists() and not overwrite:
                print(f"  [sino] {ph_name}/{art_label}  loading from disk")
                x_sino_lam = np.load(str(sino_x_path))
                n_sino_lam = np.load(str(sino_n_path))
                angles_deg = np.load(str(ang_path))
                voxel_cm   = float(vcm_path.read_text().strip())
            else:
                print(f"  [sino] {ph_name}/{art_label}  projecting...",
                      end=" ", flush=True)
                t0 = time.perf_counter()
 
                xray_raw, neut_raw = nxs.make_sinogram_pair(
                    phantom, n_angles=n_angles, kVp=kVp,
                    filter_mm_Al=filter_mm_Al, use_astra=use_astra,
                )
 
                x_art, n_art = inject_sinogram_artifacts(
                    {k: v.copy() if isinstance(v, np.ndarray) else v
                     for k, v in xray_raw.items()},
                    {k: v.copy() if isinstance(v, np.ndarray) else v
                     for k, v in neut_raw.items()},
                    cfg, rng=rng,
                )
 
                # Free raw sinograms — largest arrays, no longer needed
                del xray_raw, neut_raw
                _free_ram()
 
                x_sino_lam = x_art["sino_lam"]
                n_sino_lam = n_art["sino_lam"]
                angles_deg = x_art["angles_deg"]
                voxel_cm   = float(x_art.get("voxel_cm", phantom.voxel_cm))
 
                np.save(str(sino_x_path), x_sino_lam)
                np.save(str(sino_n_path), n_sino_lam)
                np.save(str(ang_path),    angles_deg)
                vcm_path.write_text(str(voxel_cm))
 
                # Free dict wrappers (arrays kept via x_sino_lam / n_sino_lam)
                del x_art, n_art
                _free_ram()
 
                print(f"{time.perf_counter()-t0:.1f}s")
                send_message(f"{time.perf_counter()-t0:.1f}s")
 
            x_sino_dict = {"sino_lam": x_sino_lam,
                           "angles_deg": angles_deg,
                           "voxel_cm": voxel_cm}
            n_sino_dict = {"sino_lam": n_sino_lam,
                           "angles_deg": angles_deg,
                           "voxel_cm": voxel_cm}
 
            # ── Algorithm loop ────────────────────────────────────────────────
            for alg in algorithms:
 
                done_pairs += 1
                pct    = 100.0 * done_pairs / total_pairs
                t_tot  = time.perf_counter() - t_global
                eta_s  = (t_tot / done_pairs) * (total_pairs - done_pairs)
 
                alg_dir = art_dir / alg
                alg_dir.mkdir(exist_ok=True)
                x_path  = alg_dir / "vol_xray.npy"
                n_path  = alg_dir / "vol_neutron.npy"
 
                # Skip if both exist
                if x_path.exists() and n_path.exists() and not overwrite:
                    print(f"  [{pct:5.1f}%]  SKIP  "
                          f"{ph_name}/{art_label}/{alg}  "
                          f"ETA {eta_s/60:.1f} min")
                    rss = _ram_mb()
                    for mod, p in [("xray", x_path), ("neutron", n_path)]:
                        manifest.append({
                            "phantom": ph_name, "artifact": art_label,
                            "algorithm": alg,   "modality": mod,
                            "path": str(p),     "shape": None,
                            "ram_mb_after": rss, "elapsed_s": 0.0,
                            "skipped": True,
                        })
                    continue
 
                t_alg = time.perf_counter()
 
                # Clear any stale ASTRA GPU objects before reconstruction
                _astra_clear()
                vol_x = nxs.reconstruct(
                    x_sino_dict, algorithm=alg, filter_name=filter_name,
                    n_iter=n_iter, n_subsets=n_subsets, lambda_tv=lambda_tv,
                    remove_rings=remove_rings, use_astra=use_astra,
                    clip_negative=True,
                )
 
                _astra_clear()
                vol_n = nxs.reconstruct(
                    n_sino_dict, algorithm=alg, filter_name=filter_name,
                    n_iter=n_iter, n_subsets=n_subsets, lambda_tv=lambda_tv,
                    remove_rings=remove_rings, use_astra=use_astra,
                    clip_negative=True,
                )
                _astra_clear()
 
                # Volume-domain artifacts — one call with BOTH real volumes
                vol_x, vol_n = inject_volume_artifacts(vol_x, vol_n, cfg, rng=rng)
 
                np.save(str(x_path), vol_x)
                np.save(str(n_path), vol_n)
 
                elapsed = time.perf_counter() - t_alg
 
                # Free volumes before moving to next algorithm
                del vol_x, vol_n
                _free_ram()
 
                # RAM check + progress line
                rss_mb = _check_ram(f"{ph_name}/{art_label}/{alg}")
                t_tot  = time.perf_counter() - t_global
                eta_s  = (t_tot / done_pairs) * (total_pairs - done_pairs)
                send_message(str(done_pairs)+" Done")
                send_message(str(total_pairs - done_pairs)+" Remaining")
                print(f"  [{pct:5.1f}%]  "
                      f"{ph_name}/{art_label}/{alg}  "
                      f"{elapsed:.1f}s  ETA {eta_s/60:.1f} min")
                send_message(f"  [{pct:5.1f}%]  "
                      f"{ph_name}/{art_label}/{alg}  "
                      f"{elapsed:.1f}s  ETA {eta_s/60:.1f} min")
 
                for mod, p in [("xray", x_path), ("neutron", n_path)]:
                    manifest.append({
                        "phantom":      ph_name,
                        "artifact":     art_label,
                        "algorithm":    alg,
                        "modality":     mod,
                        "path":         str(p),
                        "shape":        (N, N, N),
                        "ram_mb_after": rss_mb,
                        "elapsed_s":    elapsed / 2,
                        "skipped":      False,
                    })
 
            # After all algorithms: free sinogram arrays
            del x_sino_lam, n_sino_lam, x_sino_dict, n_sino_dict
            _free_ram()
 
        # After all artifacts: free phantom
        del phantom
        _free_ram()
 
    # ── Summary ───────────────────────────────────────────────────────────────
    elapsed_total = time.perf_counter() - t_global
    n_done    = sum(1 for m in manifest if not m["skipped"])
    n_skipped = sum(1 for m in manifest if m["skipped"])
 
    print("\n" + "=" * 76)
    print("  Batch complete.")
    print(f"  Reconstructed : {n_done}")
    print(f"  Skipped       : {n_skipped}")
    print(f"  Total time    : {elapsed_total/60:.1f} min")
    if _PSUTIL:
        print(f"  Final RAM     : proc={_ram_mb()/1e3:.2f} GB  "
              f"avail={_system_ram_available_gb():.1f} GB")
    print(f"  Output dir    : {root.resolve()}")
    print("=" * 76)

    send_message("  Batch complete.")
    send_message(f"  Reconstructed : {n_done}")
    send_message(f"  Skipped       : {n_skipped}")
    send_message(f"  Total time    : {elapsed_total/60:.1f} min")
    if _PSUTIL:
        send_message(f"  Final RAM     : proc={_ram_mb()/1e3:.2f} GB  "
              f"avail={_system_ram_available_gb():.1f} GB")
    send_message(f"  Output dir    : {root.resolve()}")
 
    manifest_path = root / "manifest.json"
    with open(manifest_path, "w") as f:
        json.dump(manifest, f, indent=2, default=str)
    print(f"  Manifest: {manifest_path}")
    send_message(f"  Manifest saved: {manifest_path}")
    
    return manifest

# %%
manifest = batch_reconstruct_all(
    output_dir = "batch_1024",
    phantoms = ["composite"],
    )
# Out:
# ============================================================================
#   Memory-efficient batch reconstruction
#   Phantoms   : ['composite']
#   Algorithms : ['FBP', 'GRIDREC', 'SIRT', 'SART', 'CGLS', 'EM', 'OSSART', 'TV_MIN', 'NESTEROV_SIRT']
#   Artifacts  : ['clean', 'noise_moderate', 'noise_low_dose', 'beam_hardening', 'bh_corrected', 'neutron_scatter', 'xray_scatter', 'detector_psf', 'ring_artifacts', 'misalignment', 'all_realistic']
#   N=1024  angles=1200  iter=30  overwrite=False
#   Volume     : 4295.0 MB each  |  Max simultaneous: 2 volumes = 8590 MB
#   Total      : 198 volumes  (850.4 GB if kept — we keep 2)
#   System RAM : 1081.0 GB total  |  1033.9 GB available now
#   RAM warn=300.0 GB  abort=off
# ============================================================================
#
# ────────────────────────────────────────────────────────────────────────────
#   [Phantom] composite  N=1024
#   [sino] composite/clean  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 259.0s
#           RAM  proc=98.38 GB  sys=12%  avail=955.4 GB  [composite/clean/FBP]
#   [  1.0%]  composite/clean/FBP  38.1s  ETA 688.2 min
#           RAM  proc=98.38 GB  sys=11%  avail=957.7 GB  [composite/clean/GRIDREC]
#   [  2.0%]  composite/clean/GRIDREC  103.9s  ETA 425.1 min
#           RAM  proc=98.38 GB  sys=12%  avail=956.4 GB  [composite/clean/SIRT]
#   [  3.0%]  composite/clean/SIRT  197.7s  ETA 386.3 min
#           RAM  proc=98.38 GB  sys=11%  avail=957.4 GB  [composite/clean/SART]
#   [  4.0%]  composite/clean/SART  47.2s  ETA 305.6 min
#           RAM  proc=98.38 GB  sys=11%  avail=957.5 GB  [composite/clean/CGLS]
#   [  5.1%]  composite/clean/CGLS  210.7s  ETA 308.2 min
#           RAM  proc=98.38 GB  sys=12%  avail=955.9 GB  [composite/clean/EM]
#   [  6.1%]  composite/clean/EM  189.2s  ETA 303.2 min
#           RAM  proc=98.38 GB  sys=11%  avail=957.4 GB  [composite/clean/OSSART]
#   [  7.1%]  composite/clean/OSSART  3434.7s  ETA 1009.6 min
#           RAM  proc=98.39 GB  sys=11%  avail=957.4 GB  [composite/clean/TV_MIN]
#   [  8.1%]  composite/clean/TV_MIN  4789.8s  ETA 1782.1 min
#           RAM  proc=98.40 GB  sys=12%  avail=957.1 GB  [composite/clean/NESTEROV_SIRT]
#   [  9.1%]  composite/clean/NESTEROV_SIRT  1291.6s  ETA 1782.3 min
#   [sino] composite/noise_moderate  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 351.0s
#           RAM  proc=98.40 GB  sys=12%  avail=955.0 GB  [composite/noise_moderate/FBP]
#   [ 10.1%]  composite/noise_moderate/FBP  38.8s  ETA 1644.3 min
#           RAM  proc=98.40 GB  sys=12%  avail=955.5 GB  [composite/noise_moderate/GRIDREC]
#   [ 11.1%]  composite/noise_moderate/GRIDREC  105.6s  ETA 1492.2 min
#           RAM  proc=98.40 GB  sys=11%  avail=957.4 GB  [composite/noise_moderate/SIRT]
#   [ 12.1%]  composite/noise_moderate/SIRT  198.3s  ETA 1376.4 min
#           RAM  proc=98.40 GB  sys=11%  avail=957.3 GB  [composite/noise_moderate/SART]
#   [ 13.1%]  composite/noise_moderate/SART  47.0s  ETA 1261.1 min
#           RAM  proc=98.40 GB  sys=12%  avail=956.0 GB  [composite/noise_moderate/CGLS]
#   [ 14.1%]  composite/noise_moderate/CGLS  211.1s  ETA 1178.9 min
#           RAM  proc=98.40 GB  sys=12%  avail=957.1 GB  [composite/noise_moderate/EM]
#   [ 15.2%]  composite/noise_moderate/EM  189.2s  ETA 1105.1 min
#           RAM  proc=98.40 GB  sys=12%  avail=957.2 GB  [composite/noise_moderate/OSSART]
#   [ 16.2%]  composite/noise_moderate/OSSART  3423.1s  ETA 1319.7 min
#           RAM  proc=98.41 GB  sys=11%  avail=957.7 GB  [composite/noise_moderate/TV_MIN]
#   [ 17.2%]  composite/noise_moderate/TV_MIN  4849.9s  ETA 1617.2 min
#           RAM  proc=98.41 GB  sys=11%  avail=957.2 GB  [composite/noise_moderate/NESTEROV_SIRT]
#   [ 18.2%]  composite/noise_moderate/NESTEROV_SIRT  1290.9s  ETA 1605.6 min
#   [sino] composite/noise_low_dose  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 350.5s
#           RAM  proc=98.41 GB  sys=11%  avail=957.7 GB  [composite/noise_low_dose/FBP]
#   [ 19.2%]  composite/noise_low_dose/FBP  37.4s  ETA 1529.7 min
#           RAM  proc=98.41 GB  sys=11%  avail=957.4 GB  [composite/noise_low_dose/GRIDREC]
#   [ 20.2%]  composite/noise_low_dose/GRIDREC  103.5s  ETA 1441.9 min
#           RAM  proc=98.41 GB  sys=12%  avail=957.0 GB  [composite/noise_low_dose/SIRT]
#   [ 21.2%]  composite/noise_low_dose/SIRT  197.6s  ETA 1368.1 min
#           RAM  proc=98.41 GB  sys=11%  avail=957.4 GB  [composite/noise_low_dose/SART]
#   [ 22.2%]  composite/noise_low_dose/SART  46.1s  ETA 1291.9 min
#           RAM  proc=98.41 GB  sys=11%  avail=957.7 GB  [composite/noise_low_dose/CGLS]
#   [ 23.2%]  composite/noise_low_dose/CGLS  210.5s  ETA 1231.3 min
#           RAM  proc=98.41 GB  sys=12%  avail=955.8 GB  [composite/noise_low_dose/EM]
#   [ 24.2%]  composite/noise_low_dose/EM  188.5s  ETA 1174.4 min
#           RAM  proc=98.41 GB  sys=12%  avail=957.2 GB  [composite/noise_low_dose/OSSART]
#   [ 25.3%]  composite/noise_low_dose/OSSART  3429.7s  ETA 1281.6 min
#           RAM  proc=98.42 GB  sys=11%  avail=959.5 GB  [composite/noise_low_dose/TV_MIN]
#   [ 26.3%]  composite/noise_low_dose/TV_MIN  4945.3s  ETA 1447.1 min
#           RAM  proc=98.43 GB  sys=11%  avail=957.6 GB  [composite/noise_low_dose/NESTEROV_SIRT]
#   [ 27.3%]  composite/noise_low_dose/NESTEROV_SIRT  1287.5s  ETA 1431.7 min
#   [sino] composite/beam_hardening  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 263.1s
#           RAM  proc=98.43 GB  sys=12%  avail=955.3 GB  [composite/beam_hardening/FBP]
#   [ 28.3%]  composite/beam_hardening/FBP  35.9s  ETA 1374.1 min
#           RAM  proc=98.43 GB  sys=12%  avail=955.8 GB  [composite/beam_hardening/GRIDREC]
#   [ 29.3%]  composite/beam_hardening/GRIDREC  102.8s  ETA 1312.2 min
#           RAM  proc=98.43 GB  sys=11%  avail=957.7 GB  [composite/beam_hardening/SIRT]
#   [ 30.3%]  composite/beam_hardening/SIRT  196.2s  ETA 1257.9 min
#           RAM  proc=98.43 GB  sys=12%  avail=957.0 GB  [composite/beam_hardening/SART]
#   [ 31.3%]  composite/beam_hardening/SART  43.8s  ETA 1201.3 min
#           RAM  proc=98.43 GB  sys=11%  avail=957.3 GB  [composite/beam_hardening/CGLS]
#   [ 32.3%]  composite/beam_hardening/CGLS  208.5s  ETA 1154.0 min
#           RAM  proc=98.43 GB  sys=11%  avail=957.3 GB  [composite/beam_hardening/EM]
#   [ 33.3%]  composite/beam_hardening/EM  187.2s  ETA 1108.6 min
#           RAM  proc=98.43 GB  sys=11%  avail=957.6 GB  [composite/beam_hardening/OSSART]
#   [ 34.3%]  composite/beam_hardening/OSSART  3420.1s  ETA 1168.6 min
#           RAM  proc=98.44 GB  sys=11%  avail=957.9 GB  [composite/beam_hardening/TV_MIN]
#   [ 35.4%]  composite/beam_hardening/TV_MIN  4907.8s  ETA 1267.4 min
#           RAM  proc=98.45 GB  sys=11%  avail=957.4 GB  [composite/beam_hardening/NESTEROV_SIRT]
#   [ 36.4%]  composite/beam_hardening/NESTEROV_SIRT  1280.7s  ETA 1250.4 min
#   [sino] composite/bh_corrected  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 271.2s
#           RAM  proc=98.45 GB  sys=12%  avail=955.0 GB  [composite/bh_corrected/FBP]
#   [ 37.4%]  composite/bh_corrected/FBP  36.4s  ETA 1205.9 min
#           RAM  proc=98.45 GB  sys=11%  avail=957.3 GB  [composite/bh_corrected/GRIDREC]
#   [ 38.4%]  composite/bh_corrected/GRIDREC  102.6s  ETA 1158.0 min
#           RAM  proc=98.45 GB  sys=12%  avail=956.3 GB  [composite/bh_corrected/SIRT]
#   [ 39.4%]  composite/bh_corrected/SIRT  196.2s  ETA 1114.8 min
#           RAM  proc=98.45 GB  sys=11%  avail=957.6 GB  [composite/bh_corrected/SART]
#   [ 40.4%]  composite/bh_corrected/SART  44.6s  ETA 1070.0 min
#           RAM  proc=98.45 GB  sys=11%  avail=957.5 GB  [composite/bh_corrected/CGLS]
#   [ 41.4%]  composite/bh_corrected/CGLS  209.0s  ETA 1031.1 min
#           RAM  proc=98.45 GB  sys=12%  avail=957.1 GB  [composite/bh_corrected/EM]
#   [ 42.4%]  composite/bh_corrected/EM  187.7s  ETA 993.5 min
#           RAM  proc=98.45 GB  sys=11%  avail=957.3 GB  [composite/bh_corrected/OSSART]
#   [ 43.4%]  composite/bh_corrected/OSSART  3445.5s  ETA 1028.1 min
#           RAM  proc=98.46 GB  sys=11%  avail=957.9 GB  [composite/bh_corrected/TV_MIN]
#   [ 44.4%]  composite/bh_corrected/TV_MIN  4899.5s  ETA 1088.9 min
#           RAM  proc=98.47 GB  sys=12%  avail=956.1 GB  [composite/bh_corrected/NESTEROV_SIRT]
#   [ 45.5%]  composite/bh_corrected/NESTEROV_SIRT  1282.8s  ETA 1071.1 min
#   [sino] composite/neutron_scatter  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 309.7s
#           RAM  proc=98.47 GB  sys=12%  avail=954.5 GB  [composite/neutron_scatter/FBP]
#   [ 46.5%]  composite/neutron_scatter/FBP  36.2s  ETA 1035.1 min
#           RAM  proc=98.47 GB  sys=12%  avail=955.7 GB  [composite/neutron_scatter/GRIDREC]
#   [ 47.5%]  composite/neutron_scatter/GRIDREC  102.5s  ETA 995.8 min
#           RAM  proc=98.47 GB  sys=12%  avail=957.0 GB  [composite/neutron_scatter/SIRT]
#   [ 48.5%]  composite/neutron_scatter/SIRT  196.2s  ETA 959.8 min
#           RAM  proc=98.47 GB  sys=12%  avail=957.0 GB  [composite/neutron_scatter/SART]
#   [ 49.5%]  composite/neutron_scatter/SART  44.2s  ETA 922.6 min
#           RAM  proc=98.47 GB  sys=12%  avail=956.1 GB  [composite/neutron_scatter/CGLS]
#   [ 50.5%]  composite/neutron_scatter/CGLS  208.9s  ETA 889.4 min
#           RAM  proc=98.47 GB  sys=11%  avail=958.2 GB  [composite/neutron_scatter/EM]
#   [ 51.5%]  composite/neutron_scatter/EM  187.5s  ETA 857.2 min
#           RAM  proc=98.47 GB  sys=12%  avail=956.1 GB  [composite/neutron_scatter/OSSART]
#   [ 52.5%]  composite/neutron_scatter/OSSART  3663.6s  ETA 878.4 min
#           RAM  proc=98.48 GB  sys=12%  avail=954.2 GB  [composite/neutron_scatter/TV_MIN]
#   [ 53.5%]  composite/neutron_scatter/TV_MIN  7010.1s  ETA 944.9 min
#           RAM  proc=98.48 GB  sys=12%  avail=956.2 GB  [composite/neutron_scatter/NESTEROV_SIRT]
#   [ 54.5%]  composite/neutron_scatter/NESTEROV_SIRT  2018.6s  ETA 935.3 min
#   [sino] composite/xray_scatter  projecting... [projector] Projecting 1200 angles (ASTRA GPU) …
#   → X-ray (polychromatic) …
#   → Neutron (thermal) …
# [projector] Done.
# 411.9s
#           RAM  proc=98.48 GB  sys=12%  avail=954.9 GB  [composite/xray_scatter/FBP]
#   [ 55.6%]  composite/xray_scatter/FBP  59.4s  ETA 904.2 min
#           RAM  proc=98.48 GB  sys=12%  avail=954.4 GB  [composite/xray_scatter/GRIDREC]
#   [ 56.6%]  composite/xray_scatter/GRIDREC  142.9s  ETA 869.7 min
#           RAM  proc=98.48 GB  sys=12%  avail=955.1 GB  [composite/xray_scatter/SIRT]
#   [ 57.6%]  composite/xray_scatter/SIRT  226.6s  ETA 837.4 min
#           RAM  proc=98.48 GB  sys=12%  avail=955.3 GB  [composite/xray_scatter/SART]
#   [ 58.6%]  composite/xray_scatter/SART  70.5s  ETA 804.2 min
#           RAM  proc=98.48 GB  sys=12%  avail=953.5 GB  [composite/xray_scatter/CGLS]
#   [ 59.6%]  composite/xray_scatter/CGLS  239.8s  ETA 774.0 min
#           RAM  proc=98.48 GB  sys=12%  avail=955.2 GB  [composite/xray_scatter/EM]
#   [ 60.6%]  composite/xray_scatter/EM  217.9s  ETA 744.4 min
#           RAM  proc=98.48 GB  sys=12%  avail=952.7 GB  [composite/xray_scatter/OSSART]
#   [ 61.6%]  composite/xray_scatter/OSSART  3946.3s  ETA 754.4 min
